# %% [markdown]
# # Calling libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # All the CSVs created in cap_read will be called and merged

# %%
rural_df = pd.read_csv('data/pct_rural_df.csv', index_col=1)
rural_df.drop(['Unnamed: 0'], axis=1, inplace=True)
rural_df.head(3)
# Out:
#           % of Rural Population
# County
# anderson                   34.7
# bedford                    55.6
# benton                     78.5

# %%
housing_df = pd.read_csv('data/pop_hous_df.csv', index_col=1)
housing_df.drop(['Unnamed: 0'], axis=1, inplace=True)
housing_df.head(3)
# Out:
#           Population_2010  Population_2000  Population_1990  Population_1980  \
# County
# anderson            75129            71330            68250            67346
# bedford             45058            37586            30411            27916
# benton              16489            16537            14524            14901
#
#           Population_1970  Housing_2010  Housing_2000  Housing_1990  \
# County
# anderson            60300         34717         32451         29323
# bedford             25039         18360         14990         12638
# benton              12126          8975          8595          7107
#
#           Housing_1980  Housing_1970
# County
# anderson         25849         20451
# bedford          10814          8820
# benton            6526          4637

# %%
industry_df = pd.read_csv('data/indus_dist.csv', index_col=1)
industry_df.drop(['Unnamed: 0'], axis=1, inplace=True)
industry_df.head(3)
# Out:
#           latitude  longitude      Avg_Dist
# county
# anderson     36.20     -84.04  32775.820230
# bedford      35.59     -86.35   4503.073082
# benton       36.23     -88.08   6487.141318

# %%
density_df = pd.read_csv('data/density_pct.csv', index_col=1)
density_df.drop(['Unnamed: 0'], axis=1, inplace=True)
density_df.rename(columns={'Hous%80-90.1' : 'Pop%80-90'},inplace=True)
density_df.head(3)
# Out:
#           Land/sq.mi  Popul_Dens  Hous_Dens  Pop%00-10  Pop%90-00  Hous%80-90  \
# County
# anderson      337.16       222.8      103.0        5.3        4.5         1.3
# bedford       473.64        95.1       38.8       19.9       23.6         8.9
# benton        394.14        41.8       22.8       -0.3       13.9        -2.5
#
#           Hous%00-10  Hous%90-00  Pop%80-90
# County
# anderson         7.0        10.7       13.4
# bedford         22.5        18.6       16.9
# benton           4.4        20.9        8.9

# %%
farm0712_df = pd.read_csv('data/farm.csv', index_col=1)
farm0712_df.drop(['Unnamed: 0'], axis=1, inplace=True)
farm0712_df.head(3)
# Out:
#           farms_number_2012  farms_number_2007  land_in_farms_acres_2012  \
# item
# anderson                441                538                     35845
# bedford                1411               1554                    232381
# benton                  463                500                     87902
#
#           land_in_farms_acres_2007  average_size_of_farm_acres_2012  \
# item
# anderson                     40135                               81
# bedford                     231206                              165
# benton                       72522                              190
#
#           average_size_of_farm_acres_2007  \
# item
# anderson                               75
# bedford                               149
# benton                                145
#
#           estimated_market_value_of_land_and_buildings_farms_2012  \
# item
# anderson                                                441
# bedford                                                1411
# benton                                                  463
#
#           estimated_market_value_of_land_and_buildings_farms_2007  1000_2012  \
# item
# anderson                                                538           209899
# bedford                                                1554           887879
# benton                                                  500           197008
#
#           1000_2007                ...                 \
# item                               ...
# anderson     214397                ...
# bedford      855072                ...
# benton       162086                ...
#
#           total_cropland_acres_2012  total_cropland_acres_2007  \
# item
# anderson                      10163                      17025
# bedford                       88563                     106886
# benton                        38546                      37596
#
#           harvested_cropland_farms_2012  harvested_cropland_farms_2007  \
# item
# anderson                            293                            350
# bedford                             951                            944
# benton                              254                            259
#
#           harvested_cropland_acres_2012  harvested_cropland_acres_2007  \
# item
# anderson                           8933                           9295
# bedford                           70961                          63198
# benton                            25166                          16651
#
#           improvements_see_text_farms_2012  improvements_see_text_farms_2007  \
# item
# anderson                              23.0                               143
# bedford                              118.0                               406
# benton                                57.0                               125
#
#           improvements_see_text_acres_2012  improvements_see_text_acres_2007
# item
# anderson                             771.0                            6703.0
# bedford                            12989.0                           34975.0
# benton                              5132.0                           11337.0
#
# [3 rows x 85 columns]

# %%
home_sale_df = pd.read_csv('data/home_sold.csv', index_col=1)
home_sale_df.drop(['Unnamed: 0'], axis=1, inplace=True)
home_sale_df.head(3)
# Out:
#           Houses_sold_2007  Houses_sold_2008  Houses_sold_2009  \
# County
# anderson                 4                42                21
# bedford                116               100                56
# benton                   2                 7                 3
#
#           Houses_sold_2010  Houses_sold_2011  Houses_sold_2012  \
# County
# anderson                27                19                 3
# bedford                 29                17                12
# benton                   3                 1                 1
#
#           Houses_sold_2013  Houses_sold_2014  Houses_sold_2015  \
# County
# anderson                25                22                26
# bedford                 11                36                51
# benton                   0                 3                 0
#
#           Houses_sold_2016  Median_Price_2007  Median_Price_2008  \
# County
# anderson                34           135950.0           176950.0
# bedford                 73           140950.0           136250.0
# benton                   1           249750.0           163500.0
#
#           Median_Price_2009  Median_Price_2010  Median_Price_2011  \
# County
# anderson           204000.0             279154           149900.0
# bedford            134950.0             128900           124000.0
# benton             108000.0             127000           300000.0
#
#           Median_Price_2012  Median_Price_2013  Median_Price_2014  \
# County
# anderson           171020.0           135000.0           172900.0
# bedford            111950.0           109900.0           122200.0
# benton             120000.0                0.0           191000.0
#
#           Median_Price_2015  Median_Price_2016
# County
# anderson           174900.0           209250.0
# bedford            138200.0           147000.0
# benton                  0.0           110000.0

# %%
farm02_df = pd.read_csv('data/farm2.csv', index_col=1)
farm02_df.drop(['Unnamed: 0'], axis=1, inplace=True)
farm02_df.head(3)
# Out:
#           farms_number_2002  land_in_farms_acres_2002  \
# item
# anderson                596                     47849
# bedford                1667                    219429
# benton                  595                     78013
#
#           average_size_of_farm_acres_2002  \
# item
# anderson                               80
# bedford                               132
# benton                                131
#
#           estimated_market_value_of_land_and_buildings_farms_2002  1000_2002  \
# item
# anderson                                                594           189411
# bedford                                                1675           561512
# benton                                                  594           115933
#
#           average_per_farm_dollars_2002  average_per_acre_dollars_2002  \
# item
# anderson                         318874                           4033
# bedford                          335231                           2494
# benton                           195174                           1580
#
#           2007_farms_by_value_group_1_to_49999  \
# item
# anderson                                    32
# bedford                                     81
# benton                                      45
#
#           2007_farms_by_value_group_50000_to_99999  \
# item
# anderson                                        59
# bedford                                        126
# benton                                          70
#
#           2007_farms_by_value_group_100000_to_199999  \
# item
# anderson                                         126
# bedford                                          296
# benton                                           129
#
#                                   ...                           \
# item                              ...
# anderson                          ...
# bedford                           ...
# benton                            ...
#
#           2002_size_of_farm_2000_acres_or_more_farms  \
# item
# anderson                                         NaN
# bedford                                          2.0
# benton                                           1.0
#
#           2002_size_of_farm_2000_acres_or_more_acres  \
# item
# anderson                                         NaN
# bedford                                          NaN
# benton                                           NaN
#
#           total_cropland_farms_2002  total_cropland_acres_2002  \
# item
# anderson                        500                      25309
# bedford                        1251                     115189
# benton                          472                      40478
#
#           harvested_cropland_farms_2002  harvested_cropland_acres_2002  \
# item
# anderson                            400                          11351
# bedford                             924                          61360
# benton                              260                          17778
#
#           cropland_used_only_for_pasture_or_grazing_farms_2007  \
# item
# anderson                                                143
# bedford                                                 406
# benton                                                  125
#
#           cropland_used_only_for_pasture_or_grazing_farms_2002  \
# item
# anderson                                                323
# bedford                                                 757
# benton                                                  267
#
#           cropland_used_only_for_pasture_or_grazing_acres_2007  \
# item
# anderson                                             6703.0
# bedford                                             34975.0
# benton                                              11337.0
#
#           cropland_used_only_for_pasture_or_grazing_acres_2002
# item
# anderson                                            11501.0
# bedford                                             47517.0
# benton                                              15739.0
#
# [3 rows x 50 columns]

# %%
pasture0712_df = pd.read_csv('data/pasture.csv', index_col=1)
pasture0712_df.drop(['Unnamed: 0'], axis=1, inplace=True)
pasture0712_df.head(3)
# Out:
#           other_cropland_farms_2012  other_cropland_farms_2007  \
# item
# anderson                         35                         64
# bedford                         125                        169
# benton                          137                        165
#
#           other_cropland_acres_2012  other_cropland_acres_2007  \
# item
# anderson                        459                     1027.0
# bedford                        4613                     8713.0
# benton                         8248                     9608.0
#
#           not_pastured_or_grazed_farms_2012  \
# item
# anderson                                 26
# bedford                                 110
# benton                                  127
#
#           not_pastured_or_grazed_farms_2007  \
# item
# anderson                                 53
# bedford                                 106
# benton                                  142
#
#           not_pastured_or_grazed_acres_2012  \
# item
# anderson                              368.0
# bedford                              3324.0
# benton                               7381.0
#
#           not_pastured_or_grazed_acres_2007  \
# item
# anderson                                795
# bedford                                4150
# benton                                 8738
#
#           cropland_on_which_all_crops_failed_farms_2012  \
# item
# anderson                                           10.0
# bedford                                            21.0
# benton                                             12.0
#
#           cropland_on_which_all_crops_failed_farms_2007  \
# item
# anderson                                             18
# bedford                                              74
# benton                                               27
#
#                                  ...                           \
# item                             ...
# anderson                         ...
# bedford                          ...
# benton                           ...
#
#           pastureland_all_types_acres_2012  pastureland_all_types_acres_2007  \
# item
# anderson                             17919                           20109.0
# bedford                             134463                          136277.0
# benton                               32263                           29238.0
#
#           reserve_enhancement_programs_farms_2012  \
# item
# anderson                                      2.0
# bedford                                      21.0
# benton                                       96.0
#
#           reserve_enhancement_programs_farms_2007  \
# item
# anderson                                      1.0
# bedford                                      29.0
# benton                                      124.0
#
#           reserve_enhancement_programs_acres_2012  \
# item
# anderson                                      NaN
# bedford                                     655.0
# benton                                     5763.0
#
#           reserve_enhancement_programs_acres_2007  \
# item
# anderson                                      NaN
# bedford                                    1541.0
# benton                                     7216.0
#
#           land_enrolled_in_crop_insurance_programs_farms_2012  \
# item
# anderson                                                2.0
# bedford                                                50.0
# benton                                                 20.0
#
#           land_enrolled_in_crop_insurance_programs_farms_2007  \
# item
# anderson                                                NaN
# bedford                                                32.0
# benton                                                  4.0
#
#           land_enrolled_in_crop_insurance_programs_acres_2012  \
# item
# anderson                                                NaN
# bedford                                             18499.0
# benton                                              12205.0
#
#           land_enrolled_in_crop_insurance_programs_acres_2007
# item
# anderson                                                NaN
# bedford                                              9883.0
# benton                                               2855.0
#
# [3 rows x 48 columns]

# %%
pasture02_df = pd.read_csv('data/pasture2.csv', index_col=1)
pasture02_df.drop(['Unnamed: 0'], axis=1, inplace=True)
pasture02_df.head(3)
# Out:
#           other_cropland_farms_2002  other_cropland_acres_2002  \
# item
# anderson                         80                     2457.0
# bedford                         215                     6312.0
# benton                          173                     6961.0
#
#           not_pastured_or_grazed_see_text_farms_2002  \
# item
# anderson                                          72
# bedford                                          191
# benton                                           167
#
#           not_pastured_or_grazed_see_text_acres_2002  \
# item
# anderson                                      2364.0
# bedford                                       5373.0
# benton                                        6895.0
#
#           cropland_on_which_all_crops_failed_farms_2002  \
# item
# anderson                                             14
# bedford                                              37
# benton                                               13
#
#           cropland_on_which_all_crops_failed_acres_2002  \
# item
# anderson                                           93.0
# bedford                                             NaN
# benton                                             66.0
#
#           cropland_in_cultivated_summer_fallow_farms_2002  \
# item
# anderson                                              NaN
# bedford                                               1.0
# benton                                                NaN
#
#           cropland_in_cultivated_summer_fallow_acres_2007  \
# item
# anderson                                              NaN
# bedford                                               NaN
# benton                                                NaN
#
#           cropland_in_cultivated_summer_fallow_acres_2002  \
# item
# anderson                                              NaN
# bedford                                               NaN
# benton                                                NaN
#
#           total_woodland_farms_2007  total_woodland_farms_2002  \
# item
# anderson                        326                        369
# bedford                         836                        859
# benton                          298                        346
#
#           total_woodland_acres_2007  total_woodland_acres_2002  \
# item
# anderson                      10799                      12974
# bedford                       36152                      38296
# benton                        17270                      19621
#
#           woodland_pastured_farms_2007  woodland_pastured_farms_2002  \
# item
# anderson                         161.0                           192
# bedford                          586.0                           610
# benton                           119.0                           175
#
#           woodland_pastured_acres_2007  woodland_pastured_acres_2002  \
# item
# anderson                        2891.0                        3790.0
# bedford                        20856.0                       22449.0
# benton                          3164.0                        5589.0
#
#           woodland_not_pastured_farms_2007
# item
# anderson                               241
# bedford                                391
# benton                                 238

# %% [markdown]
# # 1. Merge the dataframes

# %%
explan_df = rural_df.merge(housing_df, left_index=True, right_index=True, how='left')

explan_df = explan_df.merge(industry_df, left_index=True, right_index=True, how='left')

explan_df = explan_df.merge(density_df, left_index=True, right_index=True, how='left')

explan_df = explan_df.merge(home_sale_df, left_index=True, right_index=True, how='left')

explan_df = explan_df.merge(farm0712_df, left_index=True, right_index=True, how='left')

explan_df = explan_df.merge(pasture0712_df, left_index=True, right_index=True, how='left')

explan_df = explan_df.merge(pasture02_df, left_index=True, right_index=True, how='left')

# %%
# Some 2007 duplicate columns are left behind, so they have to be removed
dup_07=[]
for i in np.arange(explan_df.shape[1]):
    if explan_df.columns[i][-2:] =='_y':
        dup_07.append(explan_df.columns[i])
explan_df.drop(dup_07, axis=1, inplace=True)

# %% [markdown]
# # 2. Create a list of columns
#
# This will take place separately. A file will be created in Excel, simplifying the tables PLUS adding a description to the table for future reference.

# %%
explan_cols = explan_df.transpose()
explan_cols.isnull().sum()[explan_cols.isnull().sum() != 0]
explan_cols['brief_header']=''
explan_cols['description']=''
explan_cols.drop(list(explan_cols.columns[0:95]), axis=1, inplace=True)
explan_cols.to_csv('data/Col_Dict.csv')

# %% [markdown]
# ### 3. Make a brief heading for the columns + the definition and source of information
# ### 4. Determine the number of NaNs in rows and columns - use transpose + .isnull.sum()

# %%
nan_cnt = explan_df.isnull().sum()[explan_df.isnull().sum() != 0]
nan_cnt.sort_values(ascending=False)
# Out:
# cropland_in_cultivated_summer_fallow_acres_2002            82
# cropland_in_cultivated_summer_fallow_acres_2007_x          82
# cropland_in_cultivated_summer_fallow_acres_2012            80
# cropland_in_cultivated_summer_fallow_farms_2007            70
# 2002_size_of_farm_2000_acres_or_more_acres                 66
# 2007_size_of_farm_2000_acres_or_more_acres                 64
# cropland_in_cultivated_summer_fallow_farms_2002            60
# cropland_in_cultivated_summer_fallow_farms_2012            55
# 2012_size_of_farm_2000_acres_or_more_acres                 55
# 2007_farms_by_value_group_10000000_or_more                 52
# 2007_size_of_farm_2000_acres_or_more_farms                 40
# 2012_farms_by_value_group_10000000_or_more                 40
# cropland_on_which_all_crops_failed_acres_2002              39
# 2002_size_of_farm_2000_acres_or_more_farms                 38
# reserve_enhancement_programs_acres_2007                    38
# reserve_enhancement_programs_acres_2012                    37
# 2002_size_of_farm_1_to_9_acres_acres                       36
# cropland_on_which_all_crops_failed_acres_2012              36
# 2007_size_of_farm_1000_to_1999_acres_acres                 35
# 2002_size_of_farm_1000_to_1999_acres_acres                 35
# 2007_farms_by_value_group_5000000_to_9999999               32
# 2012_size_of_farm_1000_to_1999_acres_acres                 32
# 2012_size_of_farm_2000_acres_or_more_farms                 32
# reserve_enhancement_programs_farms_2007                    29
# 2012_size_of_farm_10_to_49_acres_acres                     26
# 2007_size_of_farm_1_to_9_acres_acres                       25
# 2012_size_of_farm_1_to_9_acres_acres                       24
# 2007_size_of_farm_220_to_259_acres_acres                   24
# cropland_on_which_all_crops_failed_acres_2007              22
# 2012_farms_by_value_group_5000000_to_9999999               19
#                                                            ..
# average_per_farm_dollars_2002                               8
# total_cropland_farms_2007                                   8
# total_cropland_acres_2012                                   8
# total_cropland_acres_2007                                   8
# harvested_cropland_farms_2012                               8
# harvested_cropland_farms_2007                               8
# harvested_cropland_acres_2012                               8
# harvested_cropland_acres_2007                               8
# improvements_see_text_farms_2007                            8
# farms_number_2002                                           8
# land_in_farms_acres_2002                                    8
# average_size_of_farm_acres_2002                             8
# estimated_market_value_of_land_and_buildings_farms_2002     8
# 1000_2002                                                   8
# average_per_acre_dollars_2002                               8
# 2002_size_of_farm_180_to_219_acres_farms                    8
# 2007_farms_by_value_group_1_to_49999                        8
# 2007_farms_by_value_group_50000_to_99999                    8
# 2007_farms_by_value_group_100000_to_199999                  8
# 2007_farms_by_value_group_200000_to_499999                  8
# 2007_farms_by_value_group_500000_to_999999                  8
# approximate_land_area_acres_2007                            8
# proportion_in_farms_percent_2007                            8
# 2002_size_of_farm_10_to_49_acres_farms                      8
# 2002_size_of_farm_50_to_69_acres_farms                      8
# 2002_size_of_farm_70_to_99_acres_farms                      8
# 2002_size_of_farm_70_to_99_acres_acres                      8
# 2002_size_of_farm_100_to_139_acres_farms                    8
# 2002_size_of_farm_140_to_179_acres_farms                    8
# farms_number_2012                                           8
# Length: 195, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.plot(nan_cnt)
plt.ylabel('NaN')
plt.show()

# %%
import collections
counter=collections.Counter(nan_cnt)

# %%
counter
# Out:
# Counter({8: 105,
#          9: 19,
#          10: 20,
#          11: 3,
#          12: 1,
#          13: 1,
#          14: 1,
#          15: 1,
#          16: 9,
#          17: 2,
#          18: 2,
#          19: 2,
#          22: 1,
#          24: 2,
#          25: 1,
#          26: 1,
#          29: 1,
#          32: 3,
#          35: 2,
#          36: 2,
#          37: 1,
#          38: 2,
#          39: 1,
#          40: 2,
#          52: 1,
#          55: 2,
#          60: 1,
#          64: 1,
#          66: 1,
#          70: 1,
#          80: 1,
#          82: 2})

# %%
list(explan_df.columns)
# Out:
# ['% of Rural Population',
#  'Population_2010',
#  'Population_2000',
#  'Population_1990',
#  'Population_1980',
#  'Population_1970',
#  'Housing_2010',
#  'Housing_2000',
#  'Housing_1990',
#  'Housing_1980',
#  'Housing_1970',
#  'latitude',
#  'longitude',
#  'Avg_Dist',
#  'Land/sq.mi',
#  'Popul_Dens',
#  'Hous_Dens',
#  'Pop%00-10',
#  'Pop%90-00',
#  'Hous%80-90',
#  'Hous%00-10',
#  'Hous%90-00',
#  'Pop%80-90',
#  'Houses_sold_2007',
#  'Houses_sold_2008',
#  'Houses_sold_2009',
#  'Houses_sold_2010',
#  'Houses_sold_2011',
#  'Houses_sold_2012',
#  'Houses_sold_2013',
#  'Houses_sold_2014',
#  'Houses_sold_2015',
#  'Houses_sold_2016',
#  'Median_Price_2007',
#  'Median_Price_2008',
#  'Median_Price_2009',
#  'Median_Price_2010',
#  'Median_Price_2011',
#  'Median_Price_2012',
#  'Median_Price_2013',
#  'Median_Price_2014',
#  'Median_Price_2015',
#  'Median_Price_2016',
#  'farms_number_2012',
#  'farms_number_2007',
#  'land_in_farms_acres_2012',
#  'land_in_farms_acres_2007',
#  'average_size_of_farm_acres_2012',
#  'average_size_of_farm_acres_2007',
#  'estimated_market_value_of_land_and_buildings_farms_2012',
#  'estimated_market_value_of_land_and_buildings_farms_2007',
#  '1000_2012',
#  '1000_2007',
#  'average_per_farm_dollars_2012',
#  'average_per_farm_dollars_2007',
#  'average_per_acre_dollars_2012',
#  'average_per_acre_dollars_2007',
#  '2012_farms_by_value_group_1_to_49999',
#  '2012_farms_by_value_group_50000_to_99999',
#  '2012_farms_by_value_group_100000_to_199999',
#  '2012_farms_by_value_group_200000_to_499999',
#  '2012_farms_by_value_group_500000_to_999999',
#  '2012_farms_by_value_group_1000000_to_1999999',
#  '2012_farms_by_value_group_2000000_to_4999999',
#  '2012_farms_by_value_group_5000000_to_9999999',
#  '2012_farms_by_value_group_10000000_or_more',
#  'approximate_land_area_acres_2012',
#  'proportion_in_farms_percent_2012',
#  '2012_size_of_farm_1_to_9_acres_farms',
#  '2012_size_of_farm_1_to_9_acres_acres',
#  '2012_size_of_farm_10_to_49_acres_farms',
#  '2012_size_of_farm_10_to_49_acres_acres',
#  '2012_size_of_farm_50_to_69_acres_farms',
#  '2012_size_of_farm_50_to_69_acres_acres',
#  '2012_size_of_farm_70_to_99_acres_farms',
#  '2012_size_of_farm_70_to_99_acres_acres',
#  '2012_size_of_farm_100_to_139_acres_farms',
#  '2012_size_of_farm_100_to_139_acres_acres',
#  '2012_size_of_farm_140_to_179_acres_farms',
#  '2012_size_of_farm_140_to_179_acres_acres',
#  '2012_size_of_farm_180_to_219_acres_farms',
#  '2012_size_of_farm_180_to_219_acres_acres',
#  '2012_size_of_farm_220_to_259_acres_farms',
#  '2012_size_of_farm_220_to_259_acres_acres',
#  '2012_size_of_farm_260_to_499_acres_farms',
#  '2012_size_of_farm_260_to_499_acres_acres',
#  '2012_size_of_farm_500_to_999_acres_farms',
#  '2012_size_of_farm_500_to_999_acres_acres',
#  '2012_size_of_farm_1000_to_1999_acres_farms',
#  '2012_size_of_farm_1000_to_1999_acres_acres',
#  '2012_size_of_farm_2000_acres_or_more_farms',
#  '2012_size_of_farm_2000_acres_or_more_acres',
#  '2007_size_of_farm_1_to_9_acres_farms',
#  '2007_size_of_farm_1_to_9_acres_acres',
#  '2007_size_of_farm_10_to_49_acres_farms',
#  '2007_size_of_farm_10_to_49_acres_acres',
#  '2007_size_of_farm_50_to_69_acres_farms',
#  '2007_size_of_farm_50_to_69_acres_acres',
#  '2007_size_of_farm_70_to_99_acres_farms',
#  '2007_size_of_farm_70_to_99_acres_acres',
#  '2007_size_of_farm_100_to_139_acres_farms',
#  '2007_size_of_farm_100_to_139_acres_acres',
#  '2007_size_of_farm_140_to_179_acres_farms',
#  '2007_size_of_farm_140_to_179_acres_acres',
#  '2007_size_of_farm_180_to_219_acres_farms',
#  '2007_size_of_farm_180_to_219_acres_acres',
#  '2007_size_of_farm_220_to_259_acres_farms',
#  '2007_size_of_farm_220_to_259_acres_acres',
#  '2007_size_of_farm_260_to_499_acres_farms',
#  '2007_size_of_farm_260_to_499_acres_acres',
#  '2007_size_of_farm_500_to_999_acres_farms',
#  '2007_size_of_farm_500_to_999_acres_acres',
#  '2007_size_of_farm_1000_to_1999_acres_farms',
#  '2007_size_of_farm_1000_to_1999_acres_acres',
#  '2007_size_of_farm_2000_acres_or_more_farms',
#  '2007_size_of_farm_2000_acres_or_more_acres',
#  'total_cropland_farms_2012',
#  'total_cropland_farms_2007',
#  'total_cropland_acres_2012',
#  'total_cropland_acres_2007',
#  'harvested_cropland_farms_2012',
#  'harvested_cropland_farms_2007',
#  'harvested_cropland_acres_2012',
#  'harvested_cropland_acres_2007',
#  'improvements_see_text_farms_2012',
#  'improvements_see_text_farms_2007',
#  'improvements_see_text_acres_2012',
#  'improvements_see_text_acres_2007',
#  'farms_number_2002',
#  'land_in_farms_acres_2002',
#  'average_size_of_farm_acres_2002',
#  'estimated_market_value_of_land_and_buildings_farms_2002',
#  '1000_2002',
#  'average_per_farm_dollars_2002',
#  'average_per_acre_dollars_2002',
#  '2007_farms_by_value_group_1_to_49999',
#  '2007_farms_by_value_group_50000_to_99999',
#  '2007_farms_by_value_group_100000_to_199999',
#  '2007_farms_by_value_group_200000_to_499999',
#  '2007_farms_by_value_group_500000_to_999999',
#  '2007_farms_by_value_group_1000000_to_1999999',
#  '2007_farms_by_value_group_2000000_to_4999999',
#  '2007_farms_by_value_group_5000000_to_9999999',
#  '2007_farms_by_value_group_10000000_or_more',
#  'approximate_land_area_acres_2007',
#  'proportion_in_farms_percent_2007',
#  '2002_size_of_farm_1_to_9_acres_farms',
#  '2002_size_of_farm_1_to_9_acres_acres',
#  '2002_size_of_farm_10_to_49_acres_farms',
#  '2002_size_of_farm_10_to_49_acres_acres',
#  '2002_size_of_farm_50_to_69_acres_farms',
#  '2002_size_of_farm_50_to_69_acres_acres',
#  '2002_size_of_farm_70_to_99_acres_farms',
#  '2002_size_of_farm_70_to_99_acres_acres',
#  '2002_size_of_farm_100_to_139_acres_farms',
#  '2002_size_of_farm_100_to_139_acres_acres',
#  '2002_size_of_farm_140_to_179_acres_farms',
#  '2002_size_of_farm_140_to_179_acres_acres',
#  '2002_size_of_farm_180_to_219_acres_farms',
#  '2002_size_of_farm_180_to_219_acres_acres',
#  '2002_size_of_farm_220_to_259_acres_farms',
#  '2002_size_of_farm_220_to_259_acres_acres',
#  '2002_size_of_farm_260_to_499_acres_farms',
#  '2002_size_of_farm_260_to_499_acres_acres',
#  '2002_size_of_farm_500_to_999_acres_farms',
#  '2002_size_of_farm_500_to_999_acres_acres',
#  '2002_size_of_farm_1000_to_1999_acres_farms',
#  '2002_size_of_farm_1000_to_1999_acres_acres',
#  '2002_size_of_farm_2000_acres_or_more_farms',
#  '2002_size_of_farm_2000_acres_or_more_acres',
#  'total_cropland_farms_2002',
#  'total_cropland_acres_2002',
#  'harvested_cropland_farms_2002',
#  'harvested_cropland_acres_2002',
#  'cropland_used_only_for_pasture_or_grazing_farms_2007',
#  'cropland_used_only_for_pasture_or_grazing_farms_2002',
#  'cropland_used_only_for_pasture_or_grazing_acres_2007',
#  'cropland_used_only_for_pasture_or_grazing_acres_2002',
#  'other_cropland_farms_2012',
#  'other_cropland_farms_2007',
#  'other_cropland_acres_2012',
#  'other_cropland_acres_2007',
#  'not_pastured_or_grazed_farms_2012',
#  'not_pastured_or_grazed_farms_2007',
#  'not_pastured_or_grazed_acres_2012',
#  'not_pastured_or_grazed_acres_2007',
#  'cropland_on_which_all_crops_failed_farms_2012',
#  'cropland_on_which_all_crops_failed_farms_2007',
#  'cropland_on_which_all_crops_failed_acres_2012',
#  'cropland_on_which_all_crops_failed_acres_2007',
#  'cropland_in_cultivated_summer_fallow_farms_2012',
#  'cropland_in_cultivated_summer_fallow_farms_2007',
#  'cropland_in_cultivated_summer_fallow_acres_2012',
#  'cropland_in_cultivated_summer_fallow_acres_2007_x',
#  'total_woodland_farms_2012',
#  'total_woodland_farms_2007_x',
#  'total_woodland_acres_2012',
#  'total_woodland_acres_2007_x',
#  'woodland_pastured_farms_2012',
#  'woodland_pastured_farms_2007_x',
#  'woodland_pastured_acres_2012',
#  'woodland_pastured_acres_2007_x',
#  'woodland_not_pastured_farms_2012',
#  'woodland_not_pastured_farms_2007_x',
#  'woodland_not_pastured_acres_2012',
#  'woodland_not_pastured_acres_2007',
#  'cropland_and_woodland_pastured_see_text_farms_2012',
#  'cropland_and_woodland_pastured_see_text_farms_2007',
#  'cropland_and_woodland_pastured_see_text_acres_2012',
#  'cropland_and_woodland_pastured_see_text_acres_2007',
#  'facilities_ponds_roads_wasteland_etc_farms_2012',
#  'facilities_ponds_roads_wasteland_etc_farms_2007',
#  'facilities_ponds_roads_wasteland_etc_acres_2012',
#  'facilities_ponds_roads_wasteland_etc_acres_2007',
#  'pastureland_all_types_farms_2012',
#  'pastureland_all_types_farms_2007',
#  'pastureland_all_types_acres_2012',
#  'pastureland_all_types_acres_2007',
#  'reserve_enhancement_programs_farms_2012',
#  'reserve_enhancement_programs_farms_2007',
#  'reserve_enhancement_programs_acres_2012',
#  'reserve_enhancement_programs_acres_2007',
#  'land_enrolled_in_crop_insurance_programs_farms_2012',
#  'land_enrolled_in_crop_insurance_programs_farms_2007',
#  'land_enrolled_in_crop_insurance_programs_acres_2012',
#  'land_enrolled_in_crop_insurance_programs_acres_2007',
#  'other_cropland_farms_2002',
#  'other_cropland_acres_2002',
#  'not_pastured_or_grazed_see_text_farms_2002',
#  'not_pastured_or_grazed_see_text_acres_2002',
#  'cropland_on_which_all_crops_failed_farms_2002',
#  'cropland_on_which_all_crops_failed_acres_2002',
#  'cropland_in_cultivated_summer_fallow_farms_2002',
#  'cropland_in_cultivated_summer_fallow_acres_2002',
#  'total_woodland_farms_2002',
#  'total_woodland_acres_2002',
#  'woodland_pastured_farms_2002',
#  'woodland_pastured_acres_2002']
