# %% [markdown]
# # Calling libraries

# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# # Functions

# %%
# This function takes latitude and longitude from two points and gives distance in miles
# 0.0175 is pi/180 (1 degree in radian)
# 3959 is earth radius in miles

def euclid(y1, x1, y2, x2):
    deltax = (x1 - x2) * 0.0175 * np.cos(y1 * 0.0175) * 3959
    deltay = (y1 - y2) * 0.0175 * 3959
    dist= np.sqrt(deltax**2 + deltay**2)
    return dist

# %%
# This function takes a string and process it as follow:
# 1. Takes out all the non-alphanumeric characters
# 2. Converts the spaces -of any length- into underscores
# 3. Lowercase alphabets
# Note: NANs converted into zero-length string to avoid error

def unitext(text_in):
    if pd.isnull(text_in) == False:
        text_in == text_in
    else:
        text_in = ' '
    
    text_01 = re.sub('[^a-zA-Z0-9\s]','',text_in) #Takes out all the non-alphanumeric characters
    text_02 = re.sub('\s+','_',text_01) # Converts the spaces -of any length- into underscores
    text_03 = str.lower(text_02)
    text_04 = re.sub('\_$','',text_03) # Trims ending space characters
    text_05 = re.sub('^\_','',text_04) # Trims begining space characters
    return text_05

# %%
# DO NOT DELETE THIS UNTIL THE DATA READING FINALIZED - USE FOR TESTING


#                                           Clark     Memph.    Chatt      Knox
# Memphis     35.076616, -90.082608         168.35.    -         258.96    
# Clarksville 36.521391, -87.385077                              145.88    195.66
# Chattanooga 35.003217, -85.257926                                        94.55
# Knoxville   35.915572, -83.916165

euclid(35.915572, -83.916165, 35.003217, -85.257926)
# Out:
# 98.233907077521295

# %% [markdown]
# # Reading raw spreadsheets

# %%
# CSVs
tab04_df = pd.read_csv('data/table_4.csv', encoding = "utf-8", names=list('abcdefghijklmnopqrst'))
tab05_df = pd.read_csv('data/table_5.csv')
tab12_df = pd.read_csv('data/tabula-12.csv', header=None)
tab13_df = pd.read_csv('data/tabula-13.csv', header=None)
tab071_df = pd.read_csv('data/table_71.csv')
tab072_df = pd.read_csv('data/table_72.csv')

# %%
# XLSX
zip_us_df = pd.read_excel('data/zip_code_database.xlsx')
hq_df = pd.read_excel('data/hqs.xlsx', header=None)
sold_df = pd.read_excel('data/18.xlsx')

# %% [markdown]
# # tab04_df
#
# Population and Households in counties

# %%
# Remove blank rows

#Replace NaNs with 0s
tab04_df.fillna(0, inplace=True)

# open a list for blank rows
blank_rows=[]

# this loop makes a list of blank rows
for i in np.arange(tab04_df.shape[0]):
    if tab04_df.iloc[i,0] == 0:
        blank_rows.append(i)
    else:
        tab04_df.iloc[i,0] = unitext(str(tab04_df.iloc[i,0]))
    
# delete blank rows
tab04_df.drop(blank_rows, inplace=True)

# %%
# Split the dataframe on original PDF page break
tab04_df_1 = tab04_df[77:]
tab04_df_2 = tab04_df[:77]

# %%
# Renaming columns

new_names=[]
for i in np.arange(tab04_df_1.shape[1]):
    if i < 8:
        snippet = 'Population_'
    else:
        snippet = 'Housing_'
    
    new_names.append(snippet+str(tab04_df_1.iloc[1,i])) 

tab04_df_1.columns=new_names

# %%
# Deleting extra columns
bad_cols=[]
for i in np.arange(tab04_df_1.shape[1]):
    if '_0' in tab04_df_1.columns.values[i]:
        bad_cols.append(i)

tab04_df_1b = tab04_df_1.drop(tab04_df_1.columns[bad_cols], axis=1)
tab04_df_1b.columns.values[0] = 'County'

# %%
# Deleting extra rows
bad_rows=[]
for i in np.arange(tab04_df_1b.shape[0]):
    if '_county' in tab04_df_1b.iloc[i,0]:
        continue
    else:
        bad_rows.append(i)
tab04_df_1b.drop(tab04_df_1b.index[bad_rows], inplace=True)
# Out:
# /Users/ghfmhf/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
tab04_df_1b['County'] = tab04_df_1b['County'].str.replace('_county','')
# Out:
# /Users/ghfmhf/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
# Renaming columns

new_names=[]
for i in np.arange(tab04_df_2.shape[1]):
    if i < 7:
        snippet = 'Population_'
    else:
        snippet = 'Housing_'
    
    new_names.append(snippet+str(tab04_df_2.iloc[1,i])) 

tab04_df_2.columns=new_names

# %%
# Deleting extra columns
bad_cols=[]
for i in np.arange(tab04_df_2.shape[1]):
    if '_0' in tab04_df_2.columns.values[i]:
        bad_cols.append(i)

tab04_df_2b = tab04_df_2.drop(tab04_df_2.columns[bad_cols], axis=1)
tab04_df_2b.columns.values[0] = 'County'

# %%
# Deleting extra rows
bad_rows=[]
for i in np.arange(tab04_df_2b.shape[0]):
    if '_county' in tab04_df_2b.iloc[i,0]:
        continue
    else:
        bad_rows.append(i)
tab04_df_2b.drop(tab04_df_2b.index[bad_rows], inplace=True)
# Out:
# /Users/ghfmhf/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
tab04_df_2b['County'] = tab04_df_2b['County'].str.replace('_county','')
# Out:
# /Users/ghfmhf/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
pop_hous_df = pd.concat([tab04_df_2b,tab04_df_1b])

pop_hous_df.to_csv('data/pop_hous_df.csv')

# %% [markdown]
# # tab05_df
# change in population density

# %%
clean_tab05_df = tab05_df.drop(['Unnamed: 1', 'Housing'], axis=1)

# %%
tab05_df.head(3)
# Out:
#         Unnamed: 0  Unnamed: 1    Housing   in square Population     unit  \
# 0              NaN  Population      units       miles    density  density
# 1        Tennessee   6,346,105  2,812,133  41,234 .90     153 .9    68 .2
# 2  Anderson County      75,129     34,717     337 .16     222 .8   103 .0
#
#   2000 to 1990 to 1980 to 2000 to.1 1990 to.1 1980 to.1
# 0    2010    2000    1990      2010      2000      1990
# 1   11 .5   16 .7    6 .2     15 .3     20 .4     15 .9
# 2    5 .3    4 .5    1 .3      7 .0     10 .7     13 .4

# %%
clean_tab05_df.columns = ['County', 'Land/sq.mi', 'Popul_Dens', 'Hous_Dens', 'Pop%00-10', 'Pop%90-00', 'Hous%80-90', 'Hous%00-10', 'Hous%90-00', 'Hous%80-90']

# %%
clean_tab05_df.drop([0,1,71,72], axis=0, inplace=True)

# %%
clean_tab05_df.drop([0,1,71,72], axis=0, inplace=True)

# %%
for i in np.arange(clean_tab05_df.shape[0]):
    clean_tab05_df.iloc[i,0] = unitext(clean_tab05_df.iloc[i,0])
    clean_tab05_df.iloc[i,0] = clean_tab05_df.iloc[i,0].replace('_county','')

# %%
clean_tab05_df = clean_tab05_df.replace('–','0')

# %%
for i in np.arange(clean_tab05_df.shape[0]):
    for j in np.arange(1, clean_tab05_df.shape[1]):
        clean_tab05_df.iloc[i,j] = clean_tab05_df.iloc[i,j].replace('–','-')
        clean_tab05_df.iloc[i,j] = clean_tab05_df.iloc[i,j].replace(' ','')
        clean_tab05_df.iloc[i,j] = clean_tab05_df.iloc[i,j].replace(',','')
        clean_tab05_df.iloc[i,j] = float(clean_tab05_df.iloc[i,j])

# %%
clean_tab05_df.replace('–','-', inplace=True)
clean_tab05_df.replace(' ','', inplace=True)

# %%
clean_tab05_df.to_csv('data/density_pct.csv')

# %% [markdown]
# # tab071_df
# % of rural population (split on page break)

# %%
# Removing extra columns
clean_tab071_df = tab071_df.drop(['Unnamed: 1', 'Unnamed: 2', 'Urban', 'Unnamed: 4',
       'Unnamed: 5', 'Rur ercenal', 'Unnamed: 7', 'Unnamed: 8'], axis = 1)

# Removing extra rows
clean_tab071_df.drop([0,1,2,3], axis = 0, inplace=True)

# Setting header
clean_tab071_df.columns = ['County', '% of Rural Population']

# Cleaning the data

# Remove junk characters, word 'county' and convert string to numbers

for i in np.arange(clean_tab071_df.shape[0]):
    clean_tab071_df.iloc[i,0] = unitext(clean_tab071_df.iloc[i,0]) 
    clean_tab071_df.iloc[i,0] = clean_tab071_df.iloc[i,0].replace('_county','')
    clean_tab071_df.iloc[i,1] = float(clean_tab071_df.iloc[i,1].replace(' ',''))

# %% [markdown]
# # tab072_df
# % of rural population (split on page break)

# %%
# Same procedure as tab071_df above

clean_tab072_df = tab072_df.drop(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
       'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8'], axis = 1)

clean_tab072_df.drop([0,1], axis = 0, inplace=True)

clean_tab072_df.columns = ['County', '% of Rural Population']

for i in np.arange(clean_tab072_df.shape[0]):
    clean_tab072_df.iloc[i,0] = unitext(clean_tab072_df.iloc[i,0]) 
    clean_tab072_df.iloc[i,0] = clean_tab072_df.iloc[i,0].replace('_county','')
    clean_tab072_df.iloc[i,1] = float(clean_tab072_df.iloc[i,1].replace(' ','.'))

# %%
pct_rural = pd.concat([clean_tab071_df, clean_tab072_df])

pct_rural.to_csv('data/pct_rural_df.csv')

# %% [markdown]
# # zip_tn_df

# %%
# Filtering TN zipcodes
zip_tn_df = zip_us_df[zip_us_df['state'] == 'TN']

# %%
# Removing extra columns
zip_tn_df.drop(['type', 'decommissioned', 'state', 'timezone', 'area_codes','world_region', 'country', 'irs_estimated_population_2014'], axis= 1, inplace=True)
# Out:
# /Users/ghfmhf/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Aviod using 'zip' since it's a python reserved word
zip_tn_df.rename(columns={"zip": "zipcode"}, inplace=True)
# Out:
# /Users/ghfmhf/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:2746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   **kwargs)

# %%
# There is a bad data in county column
zip_tn_df.isnull().sum()[zip_tn_df.isnull().sum() != 0]
# Out:
# acceptable_cities      672
# unacceptable_cities    617
# county                   1
# dtype: int64

# %%
# Marking the NaN county
zip_tn_df['county'].fillna('?', inplace=True)
# Out:
# /Users/ghfmhf/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:3660: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
# A search revealed the missing county is Obion
zip_tn_df.loc[16779,'county'] = 'obion'
# Out:
# /Users/ghfmhf/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
# Standardizing city and county names
for i in np.arange(zip_tn_df.shape[0]):
    zip_tn_df.iloc[i,1] = unitext(zip_tn_df.iloc[i,1])
    zip_tn_df.iloc[i,4] = unitext(zip_tn_df.iloc[i,4])
    zip_tn_df.iloc[i,4] = zip_tn_df.iloc[i,4].replace('_county','')
# Out:
# /Users/ghfmhf/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
zip_tn_df.to_csv('data/zip_tn.csv')

# %% [markdown]
# # hq_df
# ### industries
#
# add lat & long
#
# ### Create a list of Counties with average distance from HQs
#
# calculate distance from each industry

# %%
# Cleaning the headers
hq_df['lat'] = ''
hq_df['long'] = ''
hq_df.columns = ['idx', 'Company', 'City', 'Size', 'Lat', 'Long']
hq_df.drop(['idx'], axis=1, inplace=True)

# %%
# Some rows lack data. Removed
bad_rows = list(hq_df[hq_df['City'].isnull()].index)

hq_df.drop(bad_rows, axis=0, inplace=True)

# %%
hq_df.drop(bad_rows, axis=0, inplace=True)

# %%
for i in np.arange(hq_df.shape[0]):
    hq_df.iloc[i,1] = unitext(hq_df.iloc[i,1])

# %%
hq_coor = pd.merge(hq_df, zip_tn_df, how='left', left_on='City', right_on='primary_city')

# %%
hq_coor.drop_duplicates(subset='Company', keep='first', inplace=True)

# %%
hq_coor.columns
# Out:
# Index(['Company', 'City', 'Size', 'Lat', 'Long', 'zipcode', 'primary_city',
#        'acceptable_cities', 'unacceptable_cities', 'county', 'latitude',
#        'longitude'],
#       dtype='object')

# %%
hq_coor.drop(['City', 'Size', 'Lat', 'Long', 'zipcode', 'primary_city','acceptable_cities', 'unacceptable_cities', 'county'], axis=1, inplace=True)

# %%
bad_rows = list(hq_coor[hq_coor['latitude'].isnull() | hq_coor['longitude'].isnull()].index)
hq_coor.drop(bad_rows, axis=0, inplace=True)

# %%
hq_coor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96 entries, 0 to 2754
# Data columns (total 3 columns):
# Company      96 non-null object
# latitude     96 non-null float64
# longitude    96 non-null float64
# dtypes: float64(2), object(1)
# memory usage: 3.0+ KB

# %%
county_coor = zip_tn_df.drop_duplicates(subset='county', keep='first')

# %%
county_coor.drop(['zipcode', 'primary_city', 'acceptable_cities', 'unacceptable_cities'], axis=1,inplace=True)
# Out:
# /Users/ghfmhf/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
county_coor.sort_values(by='county', inplace=True)
# Out:
# /Users/ghfmhf/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
county_coor['Avg_Dist'] = ''
# Out:
# /Users/ghfmhf/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
for i in np.arange(county_coor.shape[0]):
    dist_sum = 0
    for j in np.arange(hq_coor.shape[0]):
        dist_sum = dist_sum + euclid(county_coor.iloc[i,1], county_coor.iloc[i,2], hq_coor.iloc[i,1], hq_coor.iloc[i,2])
    county_coor.iloc[i,3] = dist_sum
# Out:
# /Users/ghfmhf/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %% [markdown]
# # sold_df
# #### number of houses and median price over years
#
# remove extra rows
#
# rename columns
#
# standardize counties

# %%
# Renaming columns

new_names=[]
for i in np.arange(sold_df.shape[1]):
    if i < 12:
        snippet = 'Houses_sold_'
    else:
        snippet = 'Median_Price_'
    
    new_names.append(snippet+str(sold_df.iloc[0,i])) 


sold_df.columns=new_names

# removing extra rows
sold_df.drop([0,1,2,3,99,100,101],axis=0, inplace=True)

# More cleaning and renaming on columns
sold_df.drop(['Houses_sold_nan'], axis=1, inplace=True)

sold_df.rename(columns={'Houses_sold_ ': 'County'}, inplace=True)

for i in np.arange(sold_df.shape[0]):
    sold_df.iloc[i,0] = unitext(sold_df.iloc[i,0])

# %%
sold_df.to_csv('data/home_sold.csv')

# %% [markdown]
# # tab12_df
# ### area and number of lands subdivided into price and area within counties
#
# Tables successfully transformed. Next Steps:
# remove NaN rows columns
# rename columns
# make sure all values are numeric

# %%
# Removing rows that only contain NaN
nan_rows=[]
for i in np.arange(tab12_df.shape[0]):
    check_sum = tab12_df.iloc[i].isnull().sum()
    if check_sum == 14: # All NaN
        nan_rows.append(i)
tab12_df.drop(nan_rows,axis=0, inplace=True        

tab12_df.reset_index(inplace=True)
tab12_df.drop(['index'], axis=1, inplace=True)

# %%
tab12_df
# Out:
#                                                      0           1   \
# 0                                                  item   Tennessee
# 1                               farms_and_land_in_farms         NaN
# 2                                     farms_number_2012      68,050
# 3                                                  2007      79,280
# 4                              land_in_farms_acres_2012  10,867,812
# 5                                                  2007  10,969,798
# 6                       average_size_of_farm_acres_2012         160
# 7                                                  2007         138
# 8     estimated_market_value_of_land_and_buildings_f...      68,050
# 9                                                  2007      79,280
# 10                                            1000_2012  38,748,784
# 11                                                 2007  37,057,079
# 12                        average_per_farm_dollars_2012     569,416
# 13                                                 2007     467,420
# 14                        average_per_acre_dollars_2012       3,565
# 15                                                 2007       3,378
# 16                            2012_farms_by_value_group         NaN
# 17                                           1_to_49999       4,282
# 18                                       50000_to_99999       6,104
# 19                                     100000_to_199999      14,241
# 20                                     200000_to_499999      25,458
# 21                                     500000_to_999999      10,470
# 22                                   1000000_to_1999999       4,334
# 23                                   2000000_to_4999999       2,277
# 24                                   5000000_to_9999999         608
# 25                                     10000000_or_more         276
# 26                     approximate_land_area_acres_2012  26,391,606
# 27                     proportion_in_farms_percent_2012        41.2
# 28                                    2012_size_of_farm         NaN
# 29                                   1_to_9_acres_farms       3,230
# 30                                                acres      16,752
# 31                                 10_to_49_acres_farms      23,563
# 32                                                acres     646,064
# 33                                 50_to_69_acres_farms       7,704
# 34                                                acres     446,345
# 35                                 70_to_99_acres_farms       7,519
# 36                                                acres     622,055
# 37                               100_to_139_acres_farms       7,261
# 38                                                acres     842,185
# 39                               140_to_179_acres_farms       4,553
# 40                                                acres     714,453
# 41                               180_to_219_acres_farms       3,185
# 42                                                acres     629,408
# 43                               220_to_259_acres_farms       2,055
# 44                                                acres     489,524
# 45                               260_to_499_acres_farms       5,224
# 46                                                acres   1,821,129
# 47                               500_to_999_acres_farms       2,268
# 48                                                acres   1,507,906
# 49                             1000_to_1999_acres_farms         956
# 50                                                acres   1,267,223
# 51                             2000_acres_or_more_farms         532
# 52                                                acres   1,864,768
# 53                                    2007_size_of_farm         NaN
# 54                                   1_to_9_acres_farms       5,814
# 55                                                acres      31,407
# 56                                 10_to_49_acres_farms      29,396
# 57                                                acres     781,709
# 58                                 50_to_69_acres_farms       8,606
# 59                                                acres     498,582
# 60                                 70_to_99_acres_farms       8,672
# 61                                                acres     715,330
# 62                               100_to_139_acres_farms       7,680
# 63                                                acres     890,774
# 64                               140_to_179_acres_farms       4,630
# 65                                                acres     725,992
# 66                               180_to_219_acres_farms       3,113
# 67                                                acres     614,373
# 68                               220_to_259_acres_farms       2,258
# 69                                                acres     536,822
# 70                               260_to_499_acres_farms       5,476
# 71                                                acres   1,908,537
# 72                               500_to_999_acres_farms       2,287
# 73                                                acres   1,525,271
# 74                             1000_to_1999_acres_farms         892
# 75                                                acres   1,199,502
# 76                             2000_acres_or_more_farms         456
# 77                                                acres   1,541,499
# 78                       land_in_farms_according_to_use         NaN
# 79                            total_cropland_farms_2012      51,019
# 80                                                 2007      61,274
# 81                                           acres_2012   5,329,692
# 82                                                 2007   6,047,348
# 83                        harvested_cropland_farms_2012      44,908
# 84                                                 2007      48,292
# 85                                           acres_2012   4,546,788
# 86                                                 2007   4,226,440
# 87    other_pasture_and_grazing_land_that_could_have...         NaN
# 88                    used_for_crops_without_additional         NaN
# 89                     improvements_see_text_farms_2012       5,852
# 90                                                 2007      21,089
# 91                                           acres_2012     407,005
# 92                                                 2007   1,190,823
# 93                                                 item      Cannon
# 94                              farms_and_land_in_farms         NaN
# 95                                    farms_number_2012         717
# 96                                                 2007         880
# 97                             land_in_farms_acres_2012      96,262
# 98                                                 2007     116,720
# 99                      average_size_of_farm_acres_2012         134
# 100                                                2007         133
# 101   estimated_market_value_of_land_and_buildings_f...         717
# 102                                                2007         880
# 103                                           1000_2012     298,089
# 104                                                2007     377,306
# 105                       average_per_farm_dollars_2012     415,744
# 106                                                2007     428,757
# 107                       average_per_acre_dollars_2012       3,097
# 108                                                2007       3,233
# 109                           2012_farms_by_value_group         NaN
# 110                                          1_to_49999          42
# 111                                      50000_to_99999          73
# 112                                    100000_to_199999         161
# 113                                    200000_to_499999         307
# 114                                    500000_to_999999          87
# 115                                  1000000_to_1999999          27
# 116                                  2000000_to_4999999          16
# 117                                  5000000_to_9999999           3
# 118                                    10000000_or_more           1
# 119                    approximate_land_area_acres_2012     170,006
# 120                    proportion_in_farms_percent_2012        56.6
# 121                                   2012_size_of_farm         NaN
# 122                                  1_to_9_acres_farms          29
# 123                                               acres         123
# 124                                10_to_49_acres_farms         234
# 125                                               acres       6,078
# 126                                50_to_69_acres_farms          75
# 127                                               acres       4,303
# 128                                70_to_99_acres_farms          86
# 129                                               acres       7,259
# 130                              100_to_139_acres_farms          86
# 131                                               acres       9,812
# 132                              140_to_179_acres_farms          54
# 133                                               acres       8,371
# 134                              180_to_219_acres_farms          43
# 135                                               acres       8,496
# 136                              220_to_259_acres_farms          20
# 137                                               acres       4,670
# 138                              260_to_499_acres_farms          64
# 139                                               acres      22,007
# 140                              500_to_999_acres_farms          20
# 141                                               acres      13,764
# 142                            1000_to_1999_acres_farms           3
# 143                                               acres       4,445
# 144                            2000_acres_or_more_farms           3
# 145                                               acres       6,934
# 146                                   2007_size_of_farm         NaN
# 147                                  1_to_9_acres_farms          60
# 148                                               acres         (D)
# 149                                10_to_49_acres_farms         269
# 150                                               acres       7,003
# 151                                50_to_69_acres_farms          86
# 152                                               acres       4,940
# 153                                70_to_99_acres_farms         101
# 154                                               acres       8,391
# 155                              100_to_139_acres_farms         107
# 156                                               acres      12,490
# 157                              140_to_179_acres_farms          61
# 158                                               acres       9,436
# 159                              180_to_219_acres_farms          47
# 160                                               acres       9,444
# 161                              220_to_259_acres_farms          42
# 162                                               acres       9,837
# 163                              260_to_499_acres_farms          68
# 164                                               acres      24,646
# 165                              500_to_999_acres_farms          32
# 166                                               acres      19,191
# 167                            1000_to_1999_acres_farms           6
# 168                                               acres       8,532
# 169                            2000_acres_or_more_farms           1
# 170                                               acres         (D)
# 171                      land_in_farms_according_to_use         NaN
# 172                           total_cropland_farms_2012         495
# 173                                                2007         601
# 174                                          acres_2012      38,470
# 175                                                2007      48,624
# 176                       harvested_cropland_farms_2012         447
# 177                                                2007         482
# 178                                          acres_2012      33,938
# 179                                                2007      31,440
# 180   other_pasture_and_grazing_land_that_could_have...         NaN
# 181                   used_for_crops_without_additional         NaN
# 182                    improvements_see_text_farms_2012          54
# 183                                                2007         202
# 184                                          acres_2012       2,867
# 185                                                2007      14,587
# 186                                                item      Coffee
# 187                             farms_and_land_in_farms         NaN
# 188                                   farms_number_2012         895
# 189                                                2007       1,008
# 190                            land_in_farms_acres_2012     144,840
# 191                                                2007     139,945
# 192                     average_size_of_farm_acres_2012         162
# 193                                                2007         139
# 194   estimated_market_value_of_land_and_buildings_f...         895
# 195                                                2007       1,008
# 196                                           1000_2012     512,672
# 197                                                2007     490,415
# 198                       average_per_farm_dollars_2012     572,818
# 199                                                2007     486,522
# 200                       average_per_acre_dollars_2012       3,540
# 201                                                2007       3,504
# 202                           2012_farms_by_value_group         NaN
# 203                                          1_to_49999          56
# 204                                      50000_to_99999          92
# 205                                    100000_to_199999         200
# 206                                    200000_to_499999         328
# 207                                    500000_to_999999         111
# 208                                  1000000_to_1999999          56
# 209                                  2000000_to_4999999          38
# 210                                  5000000_to_9999999          12
# 211                                    10000000_or_more           2
# 212                    approximate_land_area_acres_2012     274,536
# 213                    proportion_in_farms_percent_2012        52.8
# 214                                   2012_size_of_farm         NaN
# 215                                  1_to_9_acres_farms          57
# 216                                               acres         270
# 217                                10_to_49_acres_farms         367
# 218                                               acres       9,794
# 219                                50_to_69_acres_farms          97
# 220                                               acres       5,589
# 221                                70_to_99_acres_farms          74
# 222                                               acres       6,177
# 223                              100_to_139_acres_farms          82
# 224                                               acres       9,492
# 225                              140_to_179_acres_farms          55
# 226                                               acres       8,664
# 227                              180_to_219_acres_farms          19
# 228                                               acres       3,856
# 229                              220_to_259_acres_farms          15
# 230                                               acres       3,672
# 231                              260_to_499_acres_farms          58
# 232                                               acres      20,942
# 233                              500_to_999_acres_farms          38
# 234                                               acres      24,850
# 235                            1000_to_1999_acres_farms          26
# 236                                               acres      31,414
# 237                            2000_acres_or_more_farms           7
# 238                                               acres      20,120
# 239                                   2007_size_of_farm         NaN
# 240                                  1_to_9_acres_farms          85
# 241                                               acres         445
# 242                                10_to_49_acres_farms         405
# 243                                               acres      10,218
# 244                                50_to_69_acres_farms         112
# 245                                               acres       6,358
# 246                                70_to_99_acres_farms          93
# 247                                               acres       7,512
# 248                              100_to_139_acres_farms          87
# 249                                               acres       9,939
# 250                              140_to_179_acres_farms          36
# 251                                               acres       5,798
# 252                              180_to_219_acres_farms          29
# 253                                               acres       5,665
# 254                              220_to_259_acres_farms          20
# 255                                               acres       4,833
# 256                              260_to_499_acres_farms          77
# 257                                               acres      25,648
# 258                              500_to_999_acres_farms          41
# 259                                               acres      26,896
# 260                            1000_to_1999_acres_farms          17
# 261                                               acres      20,022
# 262                            2000_acres_or_more_farms           6
# 263                                               acres      16,611
# 264                      land_in_farms_according_to_use         NaN
# 265                           total_cropland_farms_2012         667
# 266                                                2007         753
# 267                                          acres_2012      78,978
# 268                                                2007      83,786
# 269                       harvested_cropland_farms_2012         614
# 270                                                2007         641
# 271                                          acres_2012      74,092
# 272                                                2007      64,211
# 273   other_pasture_and_grazing_land_that_could_have...         NaN
# 274                   used_for_crops_without_additional         NaN
# 275                    improvements_see_text_farms_2012          72
# 276                                                2007         249
# 277                                          acres_2012       2,923
# 278                                                2007      14,421
# 279                                                item     Fayette
# 280                             farms_and_land_in_farms         NaN
# 281                                   farms_number_2012         745
# 282                                                2007         952
# 283                            land_in_farms_acres_2012     229,022
# 284                                                2007     227,434
# 285                     average_size_of_farm_acres_2012         307
# 286                                                2007         239
# 287   estimated_market_value_of_land_and_buildings_f...         745
# 288                                                2007         952
# 289                                           1000_2012     719,399
# 290                                                2007     734,892
# 291                       average_per_farm_dollars_2012     965,636
# 292                                                2007     771,945
# 293                       average_per_acre_dollars_2012       3,141
# 294                                                2007       3,231
# 295                           2012_farms_by_value_group         NaN
# 296                                          1_to_49999          30
# 297                                      50000_to_99999          35
# 298                                    100000_to_199999         121
# 299                                    200000_to_499999         273
# 300                                    500000_to_999999         132
# 301                                  1000000_to_1999999          73
# 302                                  2000000_to_4999999          51
# 303                                  5000000_to_9999999          24
# 304                                    10000000_or_more           6
# 305                    approximate_land_area_acres_2012     451,060
# 306                    proportion_in_farms_percent_2012        50.8
# 307                                   2012_size_of_farm         NaN
# 308                                  1_to_9_acres_farms          14
# 309                                               acres          54
# 310                                10_to_49_acres_farms         232
# 311                                               acres       7,000
# 312                                50_to_69_acres_farms          92
# 313                                               acres       5,272
# 314                                70_to_99_acres_farms          65
# 315                                               acres       5,335
# 316                              100_to_139_acres_farms          72
# 317                                               acres       8,381
# 318                              140_to_179_acres_farms          47
# 319                                               acres       7,418
# 320                              180_to_219_acres_farms          21
# 321                                               acres       4,236
# 322                              220_to_259_acres_farms          30
# 323                                               acres       7,168
# 324                              260_to_499_acres_farms          77
# 325                                               acres      27,214
# 326                              500_to_999_acres_farms          48
# 327                                               acres      32,267
# 328                            1000_to_1999_acres_farms          28
# 329                                               acres      36,861
# 330                            2000_acres_or_more_farms          19
# 331                                               acres      87,816
# 332                                   2007_size_of_farm         NaN
# 333                                  1_to_9_acres_farms          54
# 334                                               acres         303
# 335                                10_to_49_acres_farms         311
# 336                                               acres       8,398
# 337                                50_to_69_acres_farms         117
# 338                                               acres       6,689
# 339                                70_to_99_acres_farms          94
# 340                                               acres       7,780
# 341                              100_to_139_acres_farms          81
# 342                                               acres       9,131
# 343                              140_to_179_acres_farms          57
# 344                                               acres       8,915
# 345                              180_to_219_acres_farms          45
# 346                                               acres       9,153
# 347                              220_to_259_acres_farms          34
# 348                                               acres       8,072
# 349                              260_to_499_acres_farms          67
# 350                                               acres      22,971
# 351                              500_to_999_acres_farms          43
# 352                                               acres      28,390
# 353                            1000_to_1999_acres_farms          30
# 354                                               acres      36,288
# 355                            2000_acres_or_more_farms          19
# 356                                               acres      81,344
# 357                      land_in_farms_according_to_use         NaN
# 358                           total_cropland_farms_2012         582
# 359                                                2007         696
# 360                                          acres_2012     147,414
# 361                                                2007     154,633
# 362                       harvested_cropland_farms_2012         421
# 363                                                2007         410
# 364                                          acres_2012     115,228
# 365                                                2007     101,530
# 366   other_pasture_and_grazing_land_that_could_have...         NaN
# 367                   used_for_crops_without_additional         NaN
# 368                    improvements_see_text_farms_2012          80
# 369                                                2007         212
# 370                                          acres_2012      12,142
# 371                                                2007      23,072
# 372                                                item     Hamblen
# 373                             farms_and_land_in_farms         NaN
# 374                                   farms_number_2012         569
# 375                                                2007         715
# 376                            land_in_farms_acres_2012      58,837
# 377                                                2007      69,383
# 378                     average_size_of_farm_acres_2012         103
# 379                                                2007          97
# 380   estimated_market_value_of_land_and_buildings_f...         569
# 381                                                2007         715
# 382                                           1000_2012     275,466
# 383                                                2007     264,574
# 384                       average_per_farm_dollars_2012     484,122
# 385                                                2007     370,033
# 386                       average_per_acre_dollars_2012       4,682
# 387                                                2007       3,813
# 388                           2012_farms_by_value_group         NaN
# 389                                          1_to_49999          39
# 390                                      50000_to_99999          28
# 391                                    100000_to_199999         105
# 392                                    200000_to_499999         241
# 393                                    500000_to_999999          99
# 394                                  1000000_to_1999999          39
# 395                                  2000000_to_4999999          15
# 396                                  5000000_to_9999999           2
# 397                                    10000000_or_more           1
# 398                    approximate_land_area_acres_2012     103,155
# 399                    proportion_in_farms_percent_2012          57
# 400                                   2012_size_of_farm         NaN
# 401                                  1_to_9_acres_farms          33
# 402                                               acres         177
# 403                                10_to_49_acres_farms         248
# 404                                               acres       6,655
# 405                                50_to_69_acres_farms          68
# 406                                               acres       3,873
# 407                                70_to_99_acres_farms          60
# 408                                               acres       4,813
# 409                              100_to_139_acres_farms          45
# 410                                               acres       5,216
# 411                              140_to_179_acres_farms          33
# 412                                               acres       5,227
# 413                              180_to_219_acres_farms          23
# 414                                               acres       4,516
# 415                              220_to_259_acres_farms          15
# 416                                               acres       3,521
# 417                              260_to_499_acres_farms          33
# 418                                               acres      12,214
# 419                              500_to_999_acres_farms           5
# 420                                               acres       3,178
# 421                            1000_to_1999_acres_farms           4
# 422                                               acres         (D)
# 423                            2000_acres_or_more_farms           2
# 424                                               acres         (D)
# 425                                   2007_size_of_farm         NaN
# 426                                  1_to_9_acres_farms          53
# 427                                               acres         343
# 428                                10_to_49_acres_farms         292
# 429                                               acres       7,735
# 430                                50_to_69_acres_farms          83
# 431                                               acres       4,698
# 432                                70_to_99_acres_farms         102
# 433                                               acres       8,220
# 434                              100_to_139_acres_farms          60
# 435                                               acres       7,014
# 436                              140_to_179_acres_farms          46
# 437                                               acres       7,253
# 438                              180_to_219_acres_farms          18
# 439                                               acres       3,653
# 440                              220_to_259_acres_farms          10
# 441                                               acres       2,413
# 442                              260_to_499_acres_farms          35
# 443                                               acres      13,354
# 444                              500_to_999_acres_farms           9
# 445                                               acres       5,590
# 446                            1000_to_1999_acres_farms           7
# 447                                               acres       9,110
# 448                            2000_acres_or_more_farms           -
# 449                                               acres           -
# 450                      land_in_farms_according_to_use         NaN
# 451                           total_cropland_farms_2012         433
# 452                                                2007         589
# 453                                          acres_2012      27,349
# 454                                                2007      38,874
# 455                       harvested_cropland_farms_2012         404
# 456                                                2007         496
# 457                                          acres_2012      22,864
# 458                                                2007      21,468
# 459   other_pasture_and_grazing_land_that_could_have...         NaN
# 460                   used_for_crops_without_additional         NaN
# 461                    improvements_see_text_farms_2012          41
# 462                                                2007         234
# 463                                          acres_2012       2,623
# 464                                                2007      14,823
# 465                                                item       Henry
# 466                             farms_and_land_in_farms         NaN
# 467                                   farms_number_2012         826
# 468                                                2007         958
# 469                            land_in_farms_acres_2012     204,557
# 470                                                2007     193,416
# 471                     average_size_of_farm_acres_2012         248
# 472                                                2007         202
# 473   estimated_market_value_of_land_and_buildings_f...         826
# 474                                                2007         958
# 475                                           1000_2012     568,540
# 476                                                2007     524,643
# 477                       average_per_farm_dollars_2012     688,305
# 478                                                2007     547,644
# 479                       average_per_acre_dollars_2012       2,779
# 480                                                2007       2,713
# 481                           2012_farms_by_value_group         NaN
# 482                                          1_to_49999          60
# 483                                      50000_to_99999          91
# 484                                    100000_to_199999         191
# 485                                    200000_to_499999         267
# 486                                    500000_to_999999         104
# 487                                  1000000_to_1999999          49
# 488                                  2000000_to_4999999          42
# 489                                  5000000_to_9999999          16
# 490                                    10000000_or_more           6
# 491                    approximate_land_area_acres_2012     359,743
# 492                    proportion_in_farms_percent_2012        56.9
# 493                                   2012_size_of_farm         NaN
# 494                                  1_to_9_acres_farms          21
# 495                                               acres         107
# 496                                10_to_49_acres_farms         230
# 497                                               acres       6,535
# 498                                50_to_69_acres_farms          95
# 499                                               acres       5,406
# 500                                70_to_99_acres_farms         100
# 501                                               acres       8,291
# 502                              100_to_139_acres_farms          76
# 503                                               acres       8,994
# 504                              140_to_179_acres_farms          72
# 505                                               acres      11,223
# 506                              180_to_219_acres_farms          43
# 507                                               acres       8,325
# 508                              220_to_259_acres_farms          32
# 509                                               acres       7,619
# 510                              260_to_499_acres_farms          68
# 511                                               acres      23,349
# 512                              500_to_999_acres_farms          53
# 513                                               acres      37,710
# 514                            1000_to_1999_acres_farms          23
# 515                                               acres      31,835
# 516                            2000_acres_or_more_farms          13
# 517                                               acres      55,163
# 518                                   2007_size_of_farm         NaN
# 519                                  1_to_9_acres_farms          42
# 520                                               acres         186
# 521                                10_to_49_acres_farms         252
# 522                                               acres       7,103
# 523                                50_to_69_acres_farms         100
# 524                                               acres       5,834
# 525                                70_to_99_acres_farms         162
# 526                                               acres      13,268
# 527                              100_to_139_acres_farms         123
# 528                                               acres      14,455
# 529                              140_to_179_acres_farms          65
# 530                                               acres      10,032
# 531                              180_to_219_acres_farms          27
# 532                                               acres       5,400
# 533                              220_to_259_acres_farms          37
# 534                                               acres       8,745
# 535                              260_to_499_acres_farms          79
# 536                                               acres      28,089
# 537                              500_to_999_acres_farms          43
# 538                                               acres      30,368
# 539                            1000_to_1999_acres_farms          16
# 540                                               acres      22,690
# 541                            2000_acres_or_more_farms          12
# 542                                               acres      47,246
# 543                      land_in_farms_according_to_use         NaN
# 544                           total_cropland_farms_2012         643
# 545                                                2007         767
# 546                                          acres_2012     131,596
# 547                                                2007     126,517
# 548                       harvested_cropland_farms_2012         505
# 549                                                2007         553
# 550                                          acres_2012     112,965
# 551                                                2007      92,084
# 552   other_pasture_and_grazing_land_that_could_have...         NaN
# 553                   used_for_crops_without_additional         NaN
# 554                    improvements_see_text_farms_2012          78
# 555                                                2007         225
# 556                                          acres_2012       7,309
# 557                                                2007      15,768
# 558                                                item        Lake
# 559                             farms_and_land_in_farms         NaN
# 560                                   farms_number_2012          60
# 561                                                2007          59
# 562                            land_in_farms_acres_2012      79,747
# 563                                                2007      84,100
# 564                     average_size_of_farm_acres_2012       1,329
# 565                                                2007       1,425
# 566   estimated_market_value_of_land_and_buildings_f...          60
# 567                                                2007          59
# 568                                           1000_2012     262,434
# 569                                                2007     232,257
# 570                       average_per_farm_dollars_2012   4,373,904
# 571                                                2007   3,936,558
# 572                       average_per_acre_dollars_2012       3,291
# 573                                                2007       2,762
# 574                           2012_farms_by_value_group         NaN
# 575                                          1_to_49999           4
# 576                                      50000_to_99999           3
# 577                                    100000_to_199999           8
# 578                                    200000_to_499999          11
# 579                                    500000_to_999999           6
# 580                                  1000000_to_1999999           3
# 581                                  2000000_to_4999999          12
# 582                                  5000000_to_9999999           1
# 583                                    10000000_or_more          12
# 584                    approximate_land_area_acres_2012     106,102
# 585                    proportion_in_farms_percent_2012        75.2
# 586                                   2012_size_of_farm         NaN
# 587                                  1_to_9_acres_farms           1
# 588                                               acres         (D)
# 589                                10_to_49_acres_farms           9
# 590                                               acres         (D)
# 591                                50_to_69_acres_farms           4
# 592                                               acres         209
# 593                                70_to_99_acres_farms           3
# 594                                               acres         213
# 595                              100_to_139_acres_farms           8
# 596                                               acres         846
# 597                              140_to_179_acres_farms           1
# 598                                               acres         (D)
# 599                              180_to_219_acres_farms           1
# 600                                               acres         (D)
# 601                              220_to_259_acres_farms           3
# 602                                               acres         720
# 603                              260_to_499_acres_farms           5
# 604                                               acres         (D)
# 605                              500_to_999_acres_farms           5
# 606                                               acres       3,973
# 607                            1000_to_1999_acres_farms           3
# 608                                               acres       4,228
# 609                            2000_acres_or_more_farms          17
# 610                                               acres      67,302
# 611                                   2007_size_of_farm         NaN
# 612                                  1_to_9_acres_farms           3
# 613                                               acres           7
# 614                                10_to_49_acres_farms           1
# 615                                               acres         (D)
# 616                                50_to_69_acres_farms           3
# 617                                               acres         159
# 618                                70_to_99_acres_farms           9
# 619                                               acres         792
# 620                              100_to_139_acres_farms           1
# 621                                               acres         (D)
# 622                              140_to_179_acres_farms           4
# 623                                               acres         (D)
# 624                              180_to_219_acres_farms           -
# 625                                               acres           -
# 626                              220_to_259_acres_farms           -
# 627                                               acres           -
# 628                              260_to_499_acres_farms           3
# 629                                               acres       1,034
# 630                              500_to_999_acres_farms           9
# 631                                               acres       6,646
# 632                            1000_to_1999_acres_farms           8
# 633                                               acres      10,948
# 634                            2000_acres_or_more_farms          18
# 635                                               acres      63,755
# 636                      land_in_farms_according_to_use         NaN
# 637                           total_cropland_farms_2012          54
# 638                                                2007          57
# 639                                          acres_2012      78,116
# 640                                                2007      81,149
# 641                       harvested_cropland_farms_2012          52
# 642                                                2007          56
# 643                                          acres_2012      76,819
# 644                                                2007      78,614
# 645   other_pasture_and_grazing_land_that_could_have...         NaN
# 646                   used_for_crops_without_additional         NaN
# 647                    improvements_see_text_farms_2012           -
# 648                                                2007           2
# 649                                          acres_2012           -
# 650                                                2007         (D)
# 651                                                item       Macon
# 652                             farms_and_land_in_farms         NaN
# 653                                   farms_number_2012         879
# 654                                                2007       1,066
# 655                            land_in_farms_acres_2012     121,860
# 656                                                2007     127,801
# 657                     average_size_of_farm_acres_2012         139
# 658                                                2007         120
# 659   estimated_market_value_of_land_and_buildings_f...         879
# 660                                                2007       1,066
# 661                                           1000_2012     417,278
# 662                                                2007     417,842
# 663                       average_per_farm_dollars_2012     474,719
# 664                                                2007     391,972
# 665                       average_per_acre_dollars_2012       3,424
# 666                                                2007       3,269
# 667                           2012_farms_by_value_group         NaN
# 668                                          1_to_49999          47
# 669                                      50000_to_99999          97
# 670                                    100000_to_199999         249
# 671                                    200000_to_499999         323
# 672                                    500000_to_999999         104
# 673                                  1000000_to_1999999          41
# 674                                  2000000_to_4999999          10
# ...
# 1588         NaN     Pickett      NaN        Polk     NaN  Putnam
# 1589         NaN         NaN      NaN         NaN     NaN     NaN
# 1590         NaN         NaN      NaN         NaN     NaN     NaN
# 1591         NaN          30      NaN          43     NaN     123
# 1592         NaN          44      NaN          46     NaN     139
# 1593         NaN         791      NaN       1,055     NaN   2,462
# 1594         NaN         955      NaN       1,388     NaN   4,388
# 1595         NaN         NaN      NaN         NaN     NaN     NaN
# 1596         NaN         NaN      NaN         NaN     NaN     NaN
# 1597         NaN          26      NaN          41     NaN     105
# 1598         NaN          24      NaN          31     NaN     111
# 1599         NaN         709      NaN         913     NaN   2,024
# 1600         NaN         731      NaN         969     NaN   2,718
# 1601         NaN           6      NaN           7     NaN      26
# 1602         NaN          21      NaN          19     NaN      39
# 1603         NaN          82      NaN         142     NaN     438
# 1604         NaN         224      NaN         419     NaN   1,670
# 1605         NaN           -      NaN           -     NaN       -
# 1606         NaN           -      NaN           -     NaN       -
# 1607         NaN           -      NaN           -     NaN       -
# 1608         NaN           -      NaN           -     NaN       -
# 1609         NaN         217      NaN         150     NaN     583
# 1610         NaN         191      NaN         152     NaN     613
# 1611         NaN      10,169      NaN       9,028     NaN  30,877
# 1612         NaN       7,612      NaN       5,876     NaN  28,648
# 1613         NaN         103      NaN          67     NaN     258
# 1614         NaN         121      NaN          88     NaN     305
# 1615         NaN       2,440      NaN       2,172     NaN   8,751
# 1616         NaN       2,266      NaN       1,428     NaN   9,452
# 1617         NaN         149      NaN         112     NaN     442
# 1618         NaN         113      NaN          96     NaN     407
# 1619         NaN       7,729      NaN       6,856     NaN  22,126
# 1620         NaN       5,346      NaN       4,448     NaN  19,196
# 1621         NaN         NaN      NaN         NaN     NaN     NaN
# 1622         NaN         256      NaN         164     NaN     656
# 1623         NaN         250      NaN         212     NaN     714
# 1624         NaN      15,899      NaN       8,650     NaN  29,498
# 1625         NaN      11,916      NaN       7,505     NaN  29,527
# 1626         NaN         NaN      NaN         NaN     NaN     NaN
# 1627         NaN         195      NaN         172     NaN     601
# 1628         NaN         128      NaN         142     NaN     475
# 1629         NaN       1,205      NaN       1,624     NaN   3,859
# 1630         NaN         815      NaN       1,236     NaN   4,296
# 1631         NaN         262      NaN         184     NaN     701
# 1632         NaN         314      NaN         261     NaN     889
# 1633         NaN      20,189      NaN      12,495     NaN  44,430
# 1634         NaN      21,172      NaN      14,962     NaN  52,636
# 1635         NaN         NaN      NaN         NaN     NaN     NaN
# 1636         NaN         NaN      NaN         NaN     NaN     NaN
# 1637         NaN         NaN      NaN         NaN     NaN     NaN
# 1638         NaN           1      NaN           -     NaN       5
# 1639         NaN           3      NaN           7     NaN      12
# 1640         NaN         (D)      NaN           -     NaN     176
# 1641         NaN         (D)      NaN         286     NaN     530
# 1642         NaN          13      NaN          12     NaN       5
# 1643         NaN          13      NaN           9     NaN      15
# 1644         NaN       1,200      NaN       3,610     NaN     865
# 1645         NaN         231      NaN       3,381     NaN     272
# 1646         NaN         NaN      NaN         NaN     NaN  #NAME?
# 1647         NaN  Sequatchie   Sevier         NaN  Shelby     NaN
# 1648         NaN         NaN      NaN         NaN     NaN     NaN
# 1649         NaN         NaN      NaN         NaN     NaN     NaN
# 1650         NaN          22       73         NaN      89     NaN
# 1651         NaN          29       93         NaN     124     NaN
# 1652         NaN         387    1,504         NaN   4,678     NaN
# 1653         NaN       1,003    1,881         NaN   6,983     NaN
# 1654         NaN         NaN      NaN         NaN     NaN     NaN
# 1655         NaN         NaN      NaN         NaN     NaN     NaN
# 1656         NaN          21       71         NaN      71     NaN
# 1657         NaN          19       74         NaN     102     NaN
# 1658         NaN         306    1,426         NaN   4,298     NaN
# 1659         NaN         772    1,696         NaN   5,620     NaN
# 1660         NaN           3       10         NaN      24     NaN
# 1661         NaN          14       18         NaN      27     NaN
# 1662         NaN          81      (D)         NaN     380     NaN
# 1663         NaN         231      179         NaN   1,363     NaN
# 1664         NaN           -        1         NaN       -     NaN
# 1665         NaN           -        4         NaN       -     NaN
# 1666         NaN           -      (D)         NaN       -     NaN
# 1667         NaN           -        6         NaN       -     NaN
# 1668         NaN         129      381         NaN     177     NaN
# 1669         NaN         120      412         NaN     222     NaN
# 1670         NaN       8,346   13,738         NaN  11,174     NaN
# 1671         NaN       7,302   13,548         NaN   9,572     NaN
# 1672         NaN          59      209         NaN      70     NaN
# 1673         NaN          60      258         NaN     113     NaN
# 1674         NaN       2,873    4,439         NaN   2,633     NaN
# 1675         NaN       1,515    5,873         NaN   2,608     NaN
# 1676         NaN          90      238         NaN     132     NaN
# 1677         NaN          81      237         NaN     138     NaN
# 1678         NaN       5,473    9,299         NaN   8,541     NaN
# 1679         NaN       5,787    7,675         NaN   6,964     NaN
# 1680         NaN         NaN      NaN         NaN     NaN     NaN
# 1681         NaN         142      459         NaN     214     NaN
# 1682         NaN         143      433         NaN     312     NaN
# 1683         NaN      11,497   22,770         NaN   7,829     NaN
# 1684         NaN       8,111   18,131         NaN  10,058     NaN
# 1685         NaN         NaN      NaN         NaN     NaN     NaN
# 1686         NaN         101      343         NaN     255     NaN
# 1687         NaN          72      326         NaN     290     NaN
# 1688         NaN         832    1,921         NaN   2,466     NaN
# 1689         NaN         667    2,517         NaN   3,965     NaN
# 1690         NaN         152      488         NaN     238     NaN
# 1691         NaN         193      568         NaN     399     NaN
# 1692         NaN      16,762   28,575         NaN  13,405     NaN
# 1693         NaN      14,857   30,586         NaN  19,752     NaN
# 1694         NaN         NaN      NaN         NaN     NaN     NaN
# 1695         NaN         NaN      NaN         NaN     NaN     NaN
# 1696         NaN         NaN      NaN         NaN     NaN     NaN
# 1697         NaN           6        -         NaN      34     NaN
# 1698         NaN          11        -         NaN      70     NaN
# 1699         NaN         316        -         NaN   2,466     NaN
# 1700         NaN         516        -         NaN   3,816     NaN
# 1701         NaN           1        -         NaN      26     NaN
# 1702         NaN           1        3         NaN      25     NaN
# 1703         NaN         (D)        -         NaN  39,853     NaN
# 1704         NaN         (D)       12         NaN  42,217     NaN
# 1705         NaN         NaN      NaN         NaN  #NAME?     NaN
# 1706      Tipton   Trousdale   Unicoi         NaN   Union     NaN
# 1707         NaN         NaN      NaN         NaN     NaN     NaN
# 1708         NaN         NaN      NaN         NaN     NaN     NaN
# 1709         100          19       12         NaN      53     NaN
# 1710         164          34       17         NaN      62     NaN
# 1711       4,380         405      238         NaN   1,062     NaN
# 1712       9,849         945      (D)         NaN   1,202     NaN
# 1713         NaN         NaN      NaN         NaN     NaN     NaN
# 1714         NaN         NaN      NaN         NaN     NaN     NaN
# 1715          90          15       12         NaN      46     NaN
# 1716         137          27       12         NaN      49     NaN
# 1717       2,954         325      238         NaN     930     NaN
# 1718       5,155         704      258         NaN   1,049     NaN
# 1719          15           6        -         NaN       9     NaN
# 1720          34          12        6         NaN      13     NaN
# 1721       1,426          80        -         NaN     (D)     NaN
# 1722       4,694         241      (D)         NaN     153     NaN
# 1723           -           -        -         NaN       2     NaN
# 1724           -           -        -         NaN       -     NaN
# 1725           -           -        -         NaN     (D)     NaN
# 1726           -           -        -         NaN       -     NaN
# 1727         258         183       63         NaN     293     NaN
# 1728         268         189       56         NaN     321     NaN
# 1729      11,447       9,226    2,221         NaN  12,868     NaN
# 1730       8,498       7,552    1,749         NaN  11,865     NaN
# 1731          99         128       26         NaN     176     NaN
# 1732         160         129       26         NaN     200     NaN
# 1733       1,669       5,147      326         NaN   3,927     NaN
# 1734       2,737       5,337      245         NaN   3,856     NaN
# 1735         200          87       50         NaN     203     NaN
# 1736         141          83       40         NaN     194     NaN
# 1737       9,778       4,079    1,895         NaN   8,941     NaN
# 1738       5,761       2,215    1,504         NaN   8,009     NaN
# 1739         NaN         NaN      NaN         NaN     NaN     NaN
# 1740         261         238       56         NaN     319     NaN
# 1741         312         222       52         NaN     326     NaN
# 1742      13,845      16,908    1,157         NaN  17,915     NaN
# 1743      13,581      15,127      (D)         NaN  12,512     NaN
# 1744         NaN         NaN      NaN         NaN     NaN     NaN
# 1745         296         180       40         NaN     255     NaN
# 1746         245         165       31         NaN     206     NaN
# 1747       2,869       1,235      160         NaN   1,636     NaN
# 1748       3,105       1,556      (D)         NaN   1,724     NaN
# 1749         288         253       63         NaN     340     NaN
# 1750         398         284       63         NaN     424     NaN
# 1751      18,736      23,743    2,053         NaN  22,815     NaN
# 1752      24,600      26,389      (D)         NaN  24,965     NaN
# 1753         NaN         NaN      NaN         NaN     NaN     NaN
# 1754         NaN         NaN      NaN         NaN     NaN     NaN
# 1755         NaN         NaN      NaN         NaN     NaN     NaN
# 1756          74           1        -         NaN       5     NaN
# 1757         123           -        -         NaN       3     NaN
# 1758       2,871         (D)        -         NaN      16     NaN
# 1759       5,093           -        -         NaN       7     NaN
# 1760          66          13        -         NaN       2     NaN
# 1761          54          14        -         NaN       6     NaN
# 1762      90,297         596        -         NaN     (D)     NaN
# 1763      93,644         591        -         NaN      18     NaN
# 1764         NaN         NaN      NaN         NaN  #NAME?     NaN
# 1765         NaN  Williamson   Wilson         NaN     NaN     NaN
# 1766         NaN         NaN      NaN         NaN     NaN     NaN
# 1767         NaN         NaN      NaN         NaN     NaN     NaN
# 1768         NaN         111      145         NaN     NaN     NaN
# 1769         NaN         150      200         NaN     NaN     NaN
# 1770         NaN       2,138    3,458         NaN     NaN     NaN
# 1771         NaN       5,755    4,975         NaN     NaN     NaN
# 1772         NaN         NaN      NaN         NaN     NaN     NaN
# 1773         NaN         NaN      NaN         NaN     NaN     NaN
# 1774         NaN          91      112         NaN     NaN     NaN
# 1775         NaN         113      145         NaN     NaN     NaN
# 1776         NaN       1,815      (D)         NaN     NaN     NaN
# 1777         NaN       3,882    2,948         NaN     NaN     NaN
# 1778         NaN          32       36         NaN     NaN     NaN
# 1779         NaN          45       72         NaN     NaN     NaN
# 1780         NaN         323      935         NaN     NaN     NaN
# 1781         NaN       1,873    2,027         NaN     NaN     NaN
# 1782         NaN           -        1         NaN     NaN     NaN
# 1783         NaN           -        -         NaN     NaN     NaN
# 1784         NaN           -      (D)         NaN     NaN     NaN
# 1785         NaN           -        -         NaN     NaN     NaN
# 1786         NaN         739      938         NaN     NaN     NaN
# 1787         NaN         769      937         NaN     NaN     NaN
# 1788         NaN      30,731   46,832         NaN     NaN     NaN
# 1789         NaN      35,054   43,125         NaN     NaN     NaN
# 1790         NaN         393      620         NaN     NaN     NaN
# 1791         NaN         467      652         NaN     NaN     NaN
# 1792         NaN      13,581   27,204         NaN     NaN     NaN
# 1793         NaN      16,536   26,662         NaN     NaN     NaN
# 1794         NaN         453      465         NaN     NaN     NaN
# 1795         NaN         408      421         NaN     NaN     NaN
# 1796         NaN      17,150   19,628         NaN     NaN     NaN
# 1797         NaN      18,518   16,463         NaN     NaN     NaN
# 1798         NaN         NaN      NaN         NaN     NaN     NaN
# 1799         NaN         848    1,114         NaN     NaN     NaN
# 1800         NaN         919    1,162         NaN     NaN     NaN
# 1801         NaN      50,049   77,104         NaN     NaN     NaN
# 1802         NaN      49,877   74,355         NaN     NaN     NaN
# 1803         NaN         NaN      NaN         NaN     NaN     NaN
# 1804         NaN         764      917         NaN     NaN     NaN
# 1805         NaN         749      803         NaN     NaN     NaN
# 1806         NaN       5,648    7,122         NaN     NaN     NaN
# 1807         NaN       7,134    6,347         NaN     NaN     NaN
# 1808         NaN         916    1,202         NaN     NaN     NaN
# 1809         NaN       1,199    1,486         NaN     NaN     NaN
# 1810         NaN      68,066  110,067         NaN     NaN     NaN
# 1811         NaN      85,816  123,454         NaN     NaN     NaN
# 1812         NaN         NaN      NaN         NaN     NaN     NaN
# 1813         NaN         NaN      NaN         NaN     NaN     NaN
# 1814         NaN         NaN      NaN         NaN     NaN     NaN
# 1815         NaN           8        9         NaN     NaN     NaN
# 1816         NaN           7       15         NaN     NaN     NaN
# 1817         NaN         178       60         NaN     NaN     NaN
# 1818         NaN         134       54         NaN     NaN     NaN
# 1819         NaN           9       13         NaN     NaN     NaN
# 1820         NaN           8       14         NaN     NaN     NaN
# 1821         NaN       6,070    1,999         NaN     NaN     NaN
# 1822         NaN       5,045      513         NaN     NaN     NaN

# %%
# Standardize row headers
for i in np.arange(tab12_df.shape[0]):
    tab12_df.iloc[i,0] = unitext(tab12_df.iloc[i,0])

# %%
# Looking for the word 'item' - top left corner for transpose

corners = []
start_over = []

for i in np.arange(tab12_df.shape[0]):
    if unitext(tab12_df.iloc[i,0]) == 'item':
        corners.append(i)
        if unitext(tab12_df.iloc[i,1]) == 'tennessee': # Start_Over reveals that there are two tables in one dataframes
            start_over.append(i)
            

corners.append(tab12_df.shape[0])

# Start_Over reveals that there are two tables in one dataframes
# These two tables have to be handled separately

corners1=corners[:corners.index(start_over[1])+1]
corners2=corners[corners.index(start_over[1]):]

# %%
blank1_df = pd.DataFrame()

for i in np.arange(len(corners1)-2):
    temp = tab12_df[corners1[i] : corners1[i+1]]
    temp.reset_index(inplace=True)
    temp.drop(['index'], axis=1, inplace=True)
    temp_tran = temp.transpose()
    blank1_df = pd.concat([blank1_df,temp_tran])
# Out:
# /Users/ghfmhf/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
blank2_df = pd.DataFrame()

for i in np.arange(len(corners2)-2):
    temp = tab12_df[corners2[i] : corners2[i+1]]
    temp.reset_index(inplace=True)
    temp.drop(['index'], axis=1, inplace=True)
    temp_tran = temp.transpose()
    blank2_df = pd.concat([blank2_df,temp_tran])
# Out:
# /Users/ghfmhf/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
