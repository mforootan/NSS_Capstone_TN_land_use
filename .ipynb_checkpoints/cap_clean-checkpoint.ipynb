# %% [markdown]
# ## 2. Cleaning Data

# %% [markdown]
# ### 2.1. Calling libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 2.2. Functions

# %%
# This function should remove NANs from a list
def cleanan(input_list):
    cleaned = [i for i in input_list if pd.isnull(i) == False]
    return (cleaned)

# %% [markdown]
# ### 2.3. All the CSVs created in cap_read will be called and merged

# %%
rural_df = pd.read_csv('data/pct_rural_df.csv', index_col=1)
rural_df.drop(['Unnamed: 0'], axis=1, inplace=True)
rural_df.head(3)
# Out:
#           % of Rural Population
# County
# anderson                   34.7
# bedford                    55.6
# benton                     78.5

# %%
housing_df = pd.read_csv('data/pop_hous_df.csv', index_col=1)
housing_df.drop(['Unnamed: 0'], axis=1, inplace=True)
housing_df.head(3)
# Out:
#           Population_2010  Population_2000  Population_1990  Population_1980  \
# County
# anderson            75129            71330            68250            67346
# bedford             45058            37586            30411            27916
# benton              16489            16537            14524            14901
#
#           Population_1970  Housing_2010  Housing_2000  Housing_1990  \
# County
# anderson            60300         34717         32451         29323
# bedford             25039         18360         14990         12638
# benton              12126          8975          8595          7107
#
#           Housing_1980  Housing_1970
# County
# anderson         25849         20451
# bedford          10814          8820
# benton            6526          4637

# %%
industry_df = pd.read_csv('data/indus_dist.csv', index_col=1)
industry_df.drop(['Unnamed: 0'], axis=1, inplace=True)
industry_df.head(3)
# Out:
#           latitude  longitude      Avg_Dist
# county
# anderson     36.20     -84.04  32775.820230
# bedford      35.59     -86.35   4503.073082
# benton       36.23     -88.08   6487.141318

# %%
density_df = pd.read_csv('data/density_pct.csv', index_col=1)
density_df.drop(['Unnamed: 0'], axis=1, inplace=True)
density_df.rename(columns={'Hous%80-90.1' : 'Pop%80-90'},inplace=True)
density_df.head(3)
# Out:
#           Land/sq.mi  Popul_Dens  Hous_Dens  Pop%00-10  Pop%90-00  Hous%80-90  \
# County
# anderson      337.16       222.8      103.0        5.3        4.5         1.3
# bedford       473.64        95.1       38.8       19.9       23.6         8.9
# benton        394.14        41.8       22.8       -0.3       13.9        -2.5
#
#           Hous%00-10  Hous%90-00  Pop%80-90
# County
# anderson         7.0        10.7       13.4
# bedford         22.5        18.6       16.9
# benton           4.4        20.9        8.9

# %%
farm0712_df = pd.read_csv('data/farm.csv', index_col=1)
farm0712_df.drop(['Unnamed: 0'], axis=1, inplace=True)
farm0712_df.head(3)
# Out:
#           farms_number_2012  farms_number_2007  land_in_farms_acres_2012  \
# item
# anderson                441                538                     35845
# bedford                1411               1554                    232381
# benton                  463                500                     87902
#
#           land_in_farms_acres_2007  average_size_of_farm_acres_2012  \
# item
# anderson                     40135                               81
# bedford                     231206                              165
# benton                       72522                              190
#
#           average_size_of_farm_acres_2007  \
# item
# anderson                               75
# bedford                               149
# benton                                145
#
#           estimated_market_value_of_land_and_buildings_farms_2012  \
# item
# anderson                                                441
# bedford                                                1411
# benton                                                  463
#
#           estimated_market_value_of_land_and_buildings_farms_2007  1000_2012  \
# item
# anderson                                                538           209899
# bedford                                                1554           887879
# benton                                                  500           197008
#
#           1000_2007                ...                 \
# item                               ...
# anderson     214397                ...
# bedford      855072                ...
# benton       162086                ...
#
#           total_cropland_acres_2012  total_cropland_acres_2007  \
# item
# anderson                      10163                      17025
# bedford                       88563                     106886
# benton                        38546                      37596
#
#           harvested_cropland_farms_2012  harvested_cropland_farms_2007  \
# item
# anderson                            293                            350
# bedford                             951                            944
# benton                              254                            259
#
#           harvested_cropland_acres_2012  harvested_cropland_acres_2007  \
# item
# anderson                           8933                           9295
# bedford                           70961                          63198
# benton                            25166                          16651
#
#           improvements_see_text_farms_2012  improvements_see_text_farms_2007  \
# item
# anderson                              23.0                               143
# bedford                              118.0                               406
# benton                                57.0                               125
#
#           improvements_see_text_acres_2012  improvements_see_text_acres_2007
# item
# anderson                             771.0                            6703.0
# bedford                            12989.0                           34975.0
# benton                              5132.0                           11337.0
#
# [3 rows x 85 columns]

# %%
home_sale_df = pd.read_csv('data/home_sold.csv', index_col=1)
home_sale_df.drop(['Unnamed: 0'], axis=1, inplace=True)
home_sale_df.head(3)
# Out:
#           Houses_sold_2007  Houses_sold_2008  Houses_sold_2009  \
# County
# anderson                 4                42                21
# bedford                116               100                56
# benton                   2                 7                 3
#
#           Houses_sold_2010  Houses_sold_2011  Houses_sold_2012  \
# County
# anderson                27                19                 3
# bedford                 29                17                12
# benton                   3                 1                 1
#
#           Houses_sold_2013  Houses_sold_2014  Houses_sold_2015  \
# County
# anderson                25                22                26
# bedford                 11                36                51
# benton                   0                 3                 0
#
#           Houses_sold_2016  Median_Price_2007  Median_Price_2008  \
# County
# anderson                34           135950.0           176950.0
# bedford                 73           140950.0           136250.0
# benton                   1           249750.0           163500.0
#
#           Median_Price_2009  Median_Price_2010  Median_Price_2011  \
# County
# anderson           204000.0             279154           149900.0
# bedford            134950.0             128900           124000.0
# benton             108000.0             127000           300000.0
#
#           Median_Price_2012  Median_Price_2013  Median_Price_2014  \
# County
# anderson           171020.0           135000.0           172900.0
# bedford            111950.0           109900.0           122200.0
# benton             120000.0                0.0           191000.0
#
#           Median_Price_2015  Median_Price_2016
# County
# anderson           174900.0           209250.0
# bedford            138200.0           147000.0
# benton                  0.0           110000.0

# %%
farm02_df = pd.read_csv('data/farm2.csv', index_col=1)
farm02_df.drop(['Unnamed: 0'], axis=1, inplace=True)
farm02_df.head(3)
# Out:
#           farms_number_2002  land_in_farms_acres_2002  \
# item
# anderson                596                     47849
# bedford                1667                    219429
# benton                  595                     78013
#
#           average_size_of_farm_acres_2002  \
# item
# anderson                               80
# bedford                               132
# benton                                131
#
#           estimated_market_value_of_land_and_buildings_farms_2002  1000_2002  \
# item
# anderson                                                594           189411
# bedford                                                1675           561512
# benton                                                  594           115933
#
#           average_per_farm_dollars_2002  average_per_acre_dollars_2002  \
# item
# anderson                         318874                           4033
# bedford                          335231                           2494
# benton                           195174                           1580
#
#           2007_farms_by_value_group_1_to_49999  \
# item
# anderson                                    32
# bedford                                     81
# benton                                      45
#
#           2007_farms_by_value_group_50000_to_99999  \
# item
# anderson                                        59
# bedford                                        126
# benton                                          70
#
#           2007_farms_by_value_group_100000_to_199999  \
# item
# anderson                                         126
# bedford                                          296
# benton                                           129
#
#                                   ...                           \
# item                              ...
# anderson                          ...
# bedford                           ...
# benton                            ...
#
#           2002_size_of_farm_2000_acres_or_more_farms  \
# item
# anderson                                         NaN
# bedford                                          2.0
# benton                                           1.0
#
#           2002_size_of_farm_2000_acres_or_more_acres  \
# item
# anderson                                         NaN
# bedford                                          NaN
# benton                                           NaN
#
#           total_cropland_farms_2002  total_cropland_acres_2002  \
# item
# anderson                        500                      25309
# bedford                        1251                     115189
# benton                          472                      40478
#
#           harvested_cropland_farms_2002  harvested_cropland_acres_2002  \
# item
# anderson                            400                          11351
# bedford                             924                          61360
# benton                              260                          17778
#
#           cropland_used_only_for_pasture_or_grazing_farms_2007  \
# item
# anderson                                                143
# bedford                                                 406
# benton                                                  125
#
#           cropland_used_only_for_pasture_or_grazing_farms_2002  \
# item
# anderson                                                323
# bedford                                                 757
# benton                                                  267
#
#           cropland_used_only_for_pasture_or_grazing_acres_2007  \
# item
# anderson                                             6703.0
# bedford                                             34975.0
# benton                                              11337.0
#
#           cropland_used_only_for_pasture_or_grazing_acres_2002
# item
# anderson                                            11501.0
# bedford                                             47517.0
# benton                                              15739.0
#
# [3 rows x 50 columns]

# %%
pasture0712_df = pd.read_csv('data/pasture.csv', index_col=1)
pasture0712_df.drop(['Unnamed: 0'], axis=1, inplace=True)
pasture0712_df.head(3)
# Out:
#           other_cropland_farms_2012  other_cropland_farms_2007  \
# item
# anderson                         35                         64
# bedford                         125                        169
# benton                          137                        165
#
#           other_cropland_acres_2012  other_cropland_acres_2007  \
# item
# anderson                        459                     1027.0
# bedford                        4613                     8713.0
# benton                         8248                     9608.0
#
#           not_pastured_or_grazed_farms_2012  \
# item
# anderson                                 26
# bedford                                 110
# benton                                  127
#
#           not_pastured_or_grazed_farms_2007  \
# item
# anderson                                 53
# bedford                                 106
# benton                                  142
#
#           not_pastured_or_grazed_acres_2012  \
# item
# anderson                              368.0
# bedford                              3324.0
# benton                               7381.0
#
#           not_pastured_or_grazed_acres_2007  \
# item
# anderson                                795
# bedford                                4150
# benton                                 8738
#
#           cropland_on_which_all_crops_failed_farms_2012  \
# item
# anderson                                           10.0
# bedford                                            21.0
# benton                                             12.0
#
#           cropland_on_which_all_crops_failed_farms_2007  \
# item
# anderson                                             18
# bedford                                              74
# benton                                               27
#
#                                  ...                           \
# item                             ...
# anderson                         ...
# bedford                          ...
# benton                           ...
#
#           pastureland_all_types_acres_2012  pastureland_all_types_acres_2007  \
# item
# anderson                             17919                           20109.0
# bedford                             134463                          136277.0
# benton                               32263                           29238.0
#
#           reserve_enhancement_programs_farms_2012  \
# item
# anderson                                      2.0
# bedford                                      21.0
# benton                                       96.0
#
#           reserve_enhancement_programs_farms_2007  \
# item
# anderson                                      1.0
# bedford                                      29.0
# benton                                      124.0
#
#           reserve_enhancement_programs_acres_2012  \
# item
# anderson                                      NaN
# bedford                                     655.0
# benton                                     5763.0
#
#           reserve_enhancement_programs_acres_2007  \
# item
# anderson                                      NaN
# bedford                                    1541.0
# benton                                     7216.0
#
#           land_enrolled_in_crop_insurance_programs_farms_2012  \
# item
# anderson                                                2.0
# bedford                                                50.0
# benton                                                 20.0
#
#           land_enrolled_in_crop_insurance_programs_farms_2007  \
# item
# anderson                                                NaN
# bedford                                                32.0
# benton                                                  4.0
#
#           land_enrolled_in_crop_insurance_programs_acres_2012  \
# item
# anderson                                                NaN
# bedford                                             18499.0
# benton                                              12205.0
#
#           land_enrolled_in_crop_insurance_programs_acres_2007
# item
# anderson                                                NaN
# bedford                                              9883.0
# benton                                               2855.0
#
# [3 rows x 48 columns]

# %%
pasture02_df = pd.read_csv('data/pasture2.csv', index_col=1)
pasture02_df.drop(['Unnamed: 0'], axis=1, inplace=True)
pasture02_df.head(3)
# Out:
#           other_cropland_farms_2002  other_cropland_acres_2002  \
# item
# anderson                         80                     2457.0
# bedford                         215                     6312.0
# benton                          173                     6961.0
#
#           not_pastured_or_grazed_see_text_farms_2002  \
# item
# anderson                                          72
# bedford                                          191
# benton                                           167
#
#           not_pastured_or_grazed_see_text_acres_2002  \
# item
# anderson                                      2364.0
# bedford                                       5373.0
# benton                                        6895.0
#
#           cropland_on_which_all_crops_failed_farms_2002  \
# item
# anderson                                             14
# bedford                                              37
# benton                                               13
#
#           cropland_on_which_all_crops_failed_acres_2002  \
# item
# anderson                                           93.0
# bedford                                             NaN
# benton                                             66.0
#
#           cropland_in_cultivated_summer_fallow_farms_2002  \
# item
# anderson                                              NaN
# bedford                                               1.0
# benton                                                NaN
#
#           cropland_in_cultivated_summer_fallow_acres_2007  \
# item
# anderson                                              NaN
# bedford                                               NaN
# benton                                                NaN
#
#           cropland_in_cultivated_summer_fallow_acres_2002  \
# item
# anderson                                              NaN
# bedford                                               NaN
# benton                                                NaN
#
#           total_woodland_farms_2007  total_woodland_farms_2002  \
# item
# anderson                        326                        369
# bedford                         836                        859
# benton                          298                        346
#
#           total_woodland_acres_2007  total_woodland_acres_2002  \
# item
# anderson                      10799                      12974
# bedford                       36152                      38296
# benton                        17270                      19621
#
#           woodland_pastured_farms_2007  woodland_pastured_farms_2002  \
# item
# anderson                         161.0                           192
# bedford                          586.0                           610
# benton                           119.0                           175
#
#           woodland_pastured_acres_2007  woodland_pastured_acres_2002  \
# item
# anderson                        2891.0                        3790.0
# bedford                        20856.0                       22449.0
# benton                          3164.0                        5589.0
#
#           woodland_not_pastured_farms_2007
# item
# anderson                               241
# bedford                                391
# benton                                 238

# %% [markdown]
# ### 2.4. Merge the dataframes

# %%
explan_df = rural_df.merge(housing_df, left_index=True, right_index=True, how='left')

explan_df = explan_df.merge(industry_df, left_index=True, right_index=True, how='left')

explan_df = explan_df.merge(density_df, left_index=True, right_index=True, how='left')

explan_df = explan_df.merge(home_sale_df, left_index=True, right_index=True, how='left')

explan_df = explan_df.merge(farm0712_df, left_index=True, right_index=True, how='left')

explan_df = explan_df.merge(pasture0712_df, left_index=True, right_index=True, how='left')

explan_df = explan_df.merge(pasture02_df, left_index=True, right_index=True, how='left')

# %%
# Some 2007 duplicate columns are left behind, so they have to be removed
dup_07=[]
for i in np.arange(explan_df.shape[1]):
    if explan_df.columns[i][-2:] =='_y':
        dup_07.append(explan_df.columns[i])
explan_df.drop(dup_07, axis=1, inplace=True)

# %% [markdown]
# ### 2.5. Create a list of columns
#
# This will take place separately. A file will be created in Excel, simplifying the tables PLUS adding a description to the table for future reference.

# %%
explan_cols = explan_df.transpose()
explan_cols.isnull().sum()[explan_cols.isnull().sum() != 0]
explan_cols['brief_header']=''
explan_cols['description']=''
explan_cols.drop(list(explan_cols.columns[0:95]), axis=1, inplace=True)
# explan_cols.to_csv('data/Col_Dict2.csv')

# %% [markdown]
# ### 2.6. Make a brief heading for the columns + the definition and source of information

# %%
col_dict = pd.read_csv('data/Col_Dict.csv')
col_dict
# Out:
#                                             Unnamed: 0  brief_header  \
# 0                                % of Rural Population    pct_rur_10
# 1                                      Population_2010        pop_10
# 2                                      Population_2000        pop_00
# 3                                      Population_1990        pop_90
# 4                                      Population_1980        pop_80
# 5                                      Population_1970        pop_70
# 6                                         Housing_2010        hsg_10
# 7                                         Housing_2000        hsg_00
# 8                                         Housing_1990        hsg_90
# 9                                         Housing_1980        hsg_80
# 10                                        Housing_1970        hsg_70
# 11                                            latitude           lat
# 12                                           longitude          long
# 13                                            Avg_Dist       ind_dis
# 14                                          Land/sq.mi     land_sqmi
# 15                                          Popul_Dens       pop_den
# 16                                           Hous_Dens       hsg_den
# 17                                           Pop%00-10   pct_dpop_00
# 18                                           Pop%90-00   pct_dpop_90
# 19                                          Hous%80-90   pct_dhsg_80
# 20                                          Hous%00-10   pct_dhsg_90
# 21                                          Hous%90-00   pct_dhsg_00
# 22                                           Pop%80-90   pct_dpop_80
# 23                                    Houses_sold_2007     h_sold_07
# 24                                    Houses_sold_2008     h_sold_08
# 25                                    Houses_sold_2009     h_sold_09
# 26                                    Houses_sold_2010     h_sold_10
# 27                                    Houses_sold_2011     h_sold_11
# 28                                    Houses_sold_2012     h_sold_12
# 29                                    Houses_sold_2013     h_sold_13
# ..                                                 ...           ...
# 208  cropland_and_woodland_pastured_see_text_acres_...  ps_rg_acr_12
# 209  cropland_and_woodland_pastured_see_text_acres_...  ps_rg_acr_07
# 210    facilities_ponds_roads_wasteland_etc_farms_2012     bdg_fm_12
# 211    facilities_ponds_roads_wasteland_etc_farms_2007     bdg_fm_07
# 212    facilities_ponds_roads_wasteland_etc_acres_2012    bdg_acr_12
# 213    facilities_ponds_roads_wasteland_etc_acres_2007    bdg_acr_07
# 214                   pastureland_all_types_farms_2012     pst_fm_12
# 215                   pastureland_all_types_farms_2007     pst_fm_07
# 216                   pastureland_all_types_acres_2012    pst_acr_12
# 217                   pastureland_all_types_acres_2007    pst_acr_07
# 218            reserve_enhancement_programs_farms_2012     cnv_fm_12
# 219            reserve_enhancement_programs_farms_2007     cnv_fm_07
# 220            reserve_enhancement_programs_acres_2012    cnv_acr_12
# 221            reserve_enhancement_programs_acres_2007    cnv_acr_07
# 222  land_enrolled_in_crop_insurance_programs_farms...     ins_fm_12
# 223  land_enrolled_in_crop_insurance_programs_farms...     ins_fm_07
# 224  land_enrolled_in_crop_insurance_programs_acres...    ins_acr_12
# 225  land_enrolled_in_crop_insurance_programs_acres...    ins_acr_07
# 226                          other_cropland_farms_2002   cp_ot_fm_02
# 227                          other_cropland_acres_2002  cp_ot_acr_02
# 228         not_pastured_or_grazed_see_text_farms_2002   cp_id_fm_02
# 229         not_pastured_or_grazed_see_text_acres_2002  cp_id_acr_02
# 230      cropland_on_which_all_crops_failed_farms_2002   cp_fl_fm_02
# 231      cropland_on_which_all_crops_failed_acres_2002  cp_fl_acr_02
# 232    cropland_in_cultivated_summer_fallow_farms_2002   cp_sm_fm_02
# 233    cropland_in_cultivated_summer_fallow_acres_2002  cp_sm_acr_02
# 234                          total_woodland_farms_2002      wd_fm_02
# 235                          total_woodland_acres_2002     wd_acr_02
# 236                       woodland_pastured_farms_2002   wd_p1_fm_02
# 237                       woodland_pastured_acres_2002  wd_p1_acr_02
#
#                                            description  \
# 0                         % of rural pouplation @ 2010
# 1                            County population in 2010
# 2                            County population in 2000
# 3                            County population in 1990
# 4                            County population in 1980
# 5                            County population in 1970
# 6                         County housing units in 2010
# 7                         County housing units in 2000
# 8                         County housing units in 1990
# 9                         County housing units in 1980
# 10                        County housing units in 1970
# 11            Latitude of the county midpoint (approx)
# 12           Longitude of the county midpoint (approx)
# 13                Distance from major industries in TN
# 14                           Land area in square miles
# 15   Population density - average per square mile o...
# 16   Housing density - average per square mile of land
# 17            Percent change in population (2000-2010)
# 18            Percent change in population (1990-2000)
# 19               Percent change in housing (1980-1990)
# 20               Percent change in housing (2000-2010)
# 21               Percent change in housing (1990-2000)
# 22            Percent change in population (1980-1990)
# 23                                     Home sales 2007
# 24                                     Home sales 2008
# 25                                     Home sales 2009
# 26                                     Home sales 2010
# 27                                     Home sales 2011
# 28                                     Home sales 2012
# 29                                     Home sales 2013
# ..                                                 ...
# 208       Permanent pasture and rangeland 2012 (Acres)
# 209       Permanent pasture and rangeland 2007 (Acres)
# 210  Land in farmsteads, buildings, livestock facil...
# 211  Land in farmsteads, buildings, livestock facil...
# 212  Land in farmsteads, buildings, livestock facil...
# 213  Land in farmsteads, buildings, livestock facil...
# 214                 pastureland all types 2012 (Farms)
# 215                 pastureland all types 2007 (Farms)
# 216                 pastureland all types 2012 (Acres)
# 217                 pastureland all types 2007 (Acres)
# 218  Land enrolled in Conservation Reserve, Wetland...
# 219  Land enrolled in Conservation Reserve, Wetland...
# 220  Land enrolled in Conservation Reserve, Wetland...
# 221  Land enrolled in Conservation Reserve, Wetland...
# 222  land enrolled in crop insurance programs 2012 ...
# 223  land enrolled in crop insurance programs 2007 ...
# 224  land enrolled in crop insurance programs 2012 ...
# 225  land enrolled in crop insurance programs 2007 ...
# 226                        other cropland 2002 (Farms)
# 227                        other cropland 2002 (Acres)
# 228  Cropland idle or used for cover crops or soil ...
# 229  Cropland idle or used for cover crops or soil ...
# 230    cropland on which all crops failed 2002 (Farms)
# 231    cropland on which all crops failed 2002 (Acres)
# 232  cropland in cultivated summer fallow 2002 (Farms)
# 233  cropland in cultivated summer fallow 2002 (Acres)
# 234                        total woodland 2002 (Farms)
# 235                        total woodland 2002 (Acres)
# 236                     woodland pastured 2002 (Farms)
# 237                     woodland pastured 2002 (Acres)
#
#                                                    Ref
# 0    2010 Census of Population and Housing, Table 7...
# 1    2010 Census of Population and Housing, Table 4...
# 2    2010 Census of Population and Housing, Table 4...
# 3    2010 Census of Population and Housing, Table 4...
# 4    2010 Census of Population and Housing, Table 4...
# 5    2010 Census of Population and Housing, Table 4...
# 6    2010 Census of Population and Housing, Table 4...
# 7    2010 Census of Population and Housing, Table 4...
# 8    2010 Census of Population and Housing, Table 4...
# 9    2010 Census of Population and Housing, Table 4...
# 10   2010 Census of Population and Housing, Table 4...
# 11   http://federalgovernmentzipcodes.us/free-zipco...
# 12   http://federalgovernmentzipcodes.us/free-zipco...
# 13   https://www.zippia.com/advice/largest-companie...
# 14   2010 Census of Population and Housing, Table 5...
# 15   2010 Census of Population and Housing, Table 5...
# 16   2010 Census of Population and Housing, Table 5...
# 17   2010 Census of Population and Housing, Table 5...
# 18   2010 Census of Population and Housing, Table 5...
# 19   2010 Census of Population and Housing, Table 5...
# 20   2010 Census of Population and Housing, Table 5...
# 21   2010 Census of Population and Housing, Table 5...
# 22   2010 Census of Population and Housing, Table 5...
# 23   https://thda.org/research-planning/home-sales-...
# 24   https://thda.org/research-planning/home-sales-...
# 25   https://thda.org/research-planning/home-sales-...
# 26   https://thda.org/research-planning/home-sales-...
# 27   https://thda.org/research-planning/home-sales-...
# 28   https://thda.org/research-planning/home-sales-...
# 29   https://thda.org/research-planning/home-sales-...
# ..                                                 ...
# 208  2012 Census Volume 1, Chapter 2: County Level ...
# 209  2012 Census Volume 1, Chapter 2: County Level ...
# 210  2012 Census Volume 1, Chapter 2: County Level ...
# 211  2012 Census Volume 1, Chapter 2: County Level ...
# 212  2012 Census Volume 1, Chapter 2: County Level ...
# 213  2012 Census Volume 1, Chapter 2: County Level ...
# 214  2012 Census Volume 1, Chapter 2: County Level ...
# 215  2012 Census Volume 1, Chapter 2: County Level ...
# 216  2012 Census Volume 1, Chapter 2: County Level ...
# 217  2012 Census Volume 1, Chapter 2: County Level ...
# 218  2012 Census Volume 1, Chapter 2: County Level ...
# 219  2012 Census Volume 1, Chapter 2: County Level ...
# 220  2012 Census Volume 1, Chapter 2: County Level ...
# 221  2012 Census Volume 1, Chapter 2: County Level ...
# 222  2012 Census Volume 1, Chapter 2: County Level ...
# 223  2012 Census Volume 1, Chapter 2: County Level ...
# 224  2012 Census Volume 1, Chapter 2: County Level ...
# 225  2012 Census Volume 1, Chapter 2: County Level ...
# 226  2007 Census Volume 1, Chapter 2: County Level ...
# 227  2007 Census Volume 1, Chapter 2: County Level ...
# 228  2007 Census Volume 1, Chapter 2: County Level ...
# 229  2007 Census Volume 1, Chapter 2: County Level ...
# 230  2007 Census Volume 1, Chapter 2: County Level ...
# 231  2007 Census Volume 1, Chapter 2: County Level ...
# 232  2007 Census Volume 1, Chapter 2: County Level ...
# 233  2007 Census Volume 1, Chapter 2: County Level ...
# 234  2007 Census Volume 1, Chapter 2: County Level ...
# 235  2007 Census Volume 1, Chapter 2: County Level ...
# 236  2007 Census Volume 1, Chapter 2: County Level ...
# 237  2007 Census Volume 1, Chapter 2: County Level ...
#
# [238 rows x 4 columns]

# %%
label_dict = explan_cols.merge(col_dict, left_index=True, right_on='Unnamed: 0', how='left')

# %%
label_dict.drop(['brief_header_x', 'description_x'], axis=1, inplace=True)

# %%
label_dict.columns = ['old','new','description','source']

# %%
# This block renames the columns. A dictionary will describe what each column mean.
renam=[]
for i in np.arange(explan_df.shape[1]):
    for j in np.arange(label_dict.shape[0]):
        if explan_df.columns[i] == label_dict.iloc[j,0]:
# warren              NaN           NaN          NaN           NaN       NaN
# washington          NaN           NaN          NaN           NaN       NaN
# wayne               NaN           NaN          NaN           NaN       NaN
# weakley             NaN           NaN          NaN           NaN       NaN
# white               NaN           NaN          NaN           NaN       NaN
# williamson          NaN           NaN          NaN           NaN       NaN
# wilson              NaN           NaN          NaN           NaN       NaN
#
#             wd_acr_02  wd_p1_fm_02  wd_p1_acr_02
# County
# anderson      12974.0        192.0        3790.0
# bedford       38296.0        610.0       22449.0
# benton        19621.0        175.0        5589.0
# bledsoe       21127.0        182.0        6505.0
# blount        17460.0        424.0        8212.0
# bradley       23121.0        283.0        7998.0
# campbell       8297.0        160.0        4235.0
# cannon        30387.0        387.0       17462.0
# carroll       36829.0        288.0        8978.0
# carter        10987.0        196.0        3897.0
# cheatham      16903.0        185.0        5460.0
# chester       18628.0        132.0        3569.0
# claiborne     37872.0        552.0       12893.0
# clay          24653.0        201.0       10313.0
# cocke         20171.0        308.0        6417.0
# coffee        24493.0        306.0        9376.0
# crockett       5194.0         56.0         827.0
# cumberland    33117.0        318.0        9280.0
# davidson      11981.0        161.0        5875.0
# decatur       28411.0        169.0        8738.0
# dekalb        24743.0        320.0       12536.0
# dickson       47759.0        517.0       15830.0
# dyer           7226.0         50.0        2169.0
# fayette       42380.0        180.0        8001.0
# fentress      21720.0        177.0        5178.0
# franklin      18161.0        255.0        5206.0
# gibson        12441.0        142.0        3535.0
# giles         56198.0        849.0       35978.0
# grainger      29023.0        473.0       10551.0
# greene        40427.0       1140.0       16426.0
# ...               ...          ...           ...
# obion         18286.0        126.0        4411.0
# overton       32221.0        347.0        9437.0
# perry         19418.0         44.0        2990.0
# pickett       11590.0        131.0        2621.0
# polk           6596.0         67.0        1258.0
# putnam        32601.0        405.0       10410.0
# rhea          14695.0        161.0        3673.0
# roane         20314.0        211.0        4479.0
# robertson     22988.0        384.0        8560.0
# rutherford    46342.0        639.0       26067.0
# scott         14854.0         97.0        2470.0
# sequatchie     8149.0         47.0        1306.0
# sevier        16359.0        295.0        7309.0
# shelby        10048.0         97.0        1876.0
# smith             NaN          NaN           NaN
# stewart           NaN          NaN           NaN
# sullivan          NaN          NaN           NaN
# sumner            NaN          NaN           NaN
# tipton            NaN          NaN           NaN
# trousdale         NaN          NaN           NaN
# unicoi            NaN          NaN           NaN
# union             NaN          NaN           NaN
# van_buren         NaN          NaN           NaN
# warren            NaN          NaN           NaN
# washington        NaN          NaN           NaN
# wayne             NaN          NaN           NaN
# weakley           NaN          NaN           NaN
# white             NaN          NaN           NaN
# williamson        NaN          NaN           NaN
# wilson            NaN          NaN           NaN
#
# [95 rows x 188 columns]

# %%
# This block fills the NaNs with a random value from the same column.

for c in np.arange(nonan_df.shape[1]):
    uniq_val = cleanan(list(nonan_df.iloc[:,c].unique()))
    for r in np.arange(nonan_df.shape[0]):
        if pd.isnull(nonan_df.iloc[r,c]) == True:
            nonan_df.iloc[r,c] = np.random.choice(uniq_val)
        else:
            pass

# %%
# Make sure no NaN value is left
nonan_df.isnull().sum()[nonan_df.isnull().sum() != 0]
# Out:
# Series([], dtype: int64)

# %%
nonan_df.to_csv('data/cleaned.csv')
