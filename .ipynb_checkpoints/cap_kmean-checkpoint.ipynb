# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline

from matplotlib import*
import matplotlib.pyplot as plt
from matplotlib.cm import register_cmap
import mpld3

import seaborn as sns

from bokeh.plotting import figure, output_file, show, ColumnDataSource
from bokeh.models import HoverTool, FactorRange
from bokeh.io import show, output_file
from bokeh.models.tickers import FixedTicker
from bokeh.models import Arrow, OpenHead, NormalHead, VeeHead

from pprint import pprint

# %%
# import geopandas as gpd
# import pysal as ps
#from pysal.contrib.viz import mapping as maps

# %%
from scipy.cluster.hierarchy import fcluster
from scipy.cluster.hierarchy import linkage, dendrogram
from scipy import stats

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE
from sklearn.preprocessing import normalize
from sklearn.preprocessing import Normalizer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA as sklearnPCA

# %%
def kcolor(num):
    color_code = ['red','green','blue','purple','orange','deepskyblue','darkseagreen', 'gray','yellow','orchid','tan', 'palevioletred','brown']
    if num in np.arange(0, len(color_code)):
        pickolor = color_code[num]
    else:
        pickolor = 'black'
    
    return pickolor

# %%
pc123_df = pd.read_csv('data/plots.csv', index_col=0)
vec123_df = pd.read_csv('data/vectors.csv', index_col=0)

# %%
pc12_df = pc123_df.drop(['PC3'], axis=1)
pc13_df = pc123_df.drop(['PC2'], axis=1)

# %%
pc12_a = np.array(pc12_df)

# Create a KMeans instance: model
model = KMeans(n_clusters=3)

# Fit model to points
model.fit(pc12_a)

# Determine the cluster labels of new_points: labels
labels = model.predict(pc12_a)

color_list = []
for i in np.arange(len(labels)):
    color_list.append(kcolor(labels[i]))

pc12_df['cluster'] = color_list

# %%
pc12_df
# Out:
#                   PC1        PC2 cluster
# anderson    -7.332806   2.383207     red
# bedford     16.606917  -1.754641   green
# benton      -4.443341  -2.766427     red
# bledsoe     -2.663562  -2.707438     red
# blount       3.629524   4.585776    blue
# bradley      0.006174   3.420939    blue
# campbell    -8.624536   1.662236     red
# cannon       0.836037  -1.248077    blue
# carroll      3.616707  -6.814513    blue
# carter      -7.197445   1.736370     red
# cheatham    -5.463332   1.685779     red
# chester     -5.656154  -2.333820     red
# claiborne    6.288910  -0.960461    blue
# clay        -5.341116  -3.578210     red
# cocke       -2.555650   0.398423     red
# coffee       3.035993   0.001744    blue
# crockett    -6.854242  -4.645187     red
# cumberland   2.613458   1.162961    blue
# davidson    -6.596236  22.251171     red
# decatur     -5.019564  -3.250190     red
# dekalb      -1.261544  -0.689281    blue
# dickson     10.080655  -0.100997    blue
# dyer        -4.126518  -4.196370     red
# fayette      5.815291  -3.978516    blue
# fentress    -3.571801  -1.040406     red
# franklin     2.253155  -0.306818    blue
# gibson       4.510026  -5.882745    blue
# giles       23.131744  -4.305810   green
# grainger     2.748496   0.044063    blue
# greene      33.088964   1.364316   green
# ...               ...        ...     ...
# obion       -1.272476  -5.753233    blue
# overton      3.783564  -1.137669    blue
# perry       -9.123862  -3.183168     red
# pickett     -9.359003  -0.659944     red
# polk       -10.841460  -0.068243     red
# putnam       3.512645   2.099552    blue
# rhea        -6.714455   0.041290     red
# roane       -5.158719   1.149655     red
# robertson   10.733262  -0.074986   green
# rutherford  13.185126  10.892867   green
# scott       -9.530157  -0.777451     red
# sequatchie -11.230948   0.340787     red
# sevier      -2.818430   4.204760     red
# shelby      -5.322759  18.135126     red
# smith        3.760115  -2.051070    blue
# stewart     -6.749291  -1.101652     red
# sullivan     2.954572   5.790131    blue
# sumner      12.452913   7.482642   green
# tipton      -3.259862   0.216538     red
# trousdale   -9.297469  -0.955362     red
# unicoi     -10.872230  -0.587590     red
# union       -6.794713   0.449296     red
# van_buren   -0.000001  -3.529196    blue
# warren      -0.537061  -1.370546    blue
# washington  -1.276019   3.071330    blue
# wayne        0.738375  -4.981002    blue
# weakley      0.775175  -1.824089    blue
# white        0.356326  -1.918548    blue
# williamson   2.507069  12.934919    blue
# wilson       2.258222   6.417557    blue
#
# [95 rows x 3 columns]

# %%
output_file("pc1vs2k.html")


# SourceP and SourceV are hover texts for data points and eigenvectors respectively
sourcep = ColumnDataSource(data=dict(
    x=pc12_df['PC1'],
    y=pc12_df['PC2'],
    desc=list(pc12_df.index),
))

sourcev = ColumnDataSource(data=dict(
    x=vec123_df['PC1'],
    y=vec123_df['PC2'],
    desc=list(vec123_df.index),
))


hover = HoverTool(tooltips=[("", "@desc"),])

p = figure(title="PC1 vs PC2 clustering",
           plot_width=1300, plot_height=700,
           x_axis_label='Principal Component 1',
          y_axis_label='Principal Component 2', 
           tools=[hover])

pc_x = pc12_df['PC1']
pc_y = pc12_df['PC2']
pc_c = pc12_df['cluster']

p.circle(pc_x, pc_y, color=None, fill_color=pc_c, size=9, fill_alpha = 0.5, source = sourcep)

rescale = 50
pc1_vx = rescale * vec123_df['PC1']
pc1_vy2 = rescale * vec123_df['PC2']


p.segment(0,0, pc1_vx, pc1_vy2, line_color="black", line_width = 1, line_alpha = 0.1)

p.triangle(pc1_vx, pc1_vy2, color = None, size=5, fill_color="black", fill_alpha = 0.5, angle=-np.abs(pc1_vx) * np.arctan(pc1_vx/pc1_vy2), source = sourcev)

show(p)
# Out:
# /Users/ghfmhf/anaconda3/lib/python3.6/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)
# /Users/ghfmhf/anaconda3/lib/python3.6/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)
# /Users/ghfmhf/anaconda3/lib/python3.6/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)
# /Users/ghfmhf/anaconda3/lib/python3.6/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)
# /Users/ghfmhf/anaconda3/lib/python3.6/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)
# /Users/ghfmhf/anaconda3/lib/python3.6/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)

# %%
vec123_df
# Out:
#                    PC1       PC2       PC3
# pct_rur_10   -0.026517 -0.138636 -0.085689
# pop_10        0.004598  0.167580  0.066838
# pop_00        0.002209  0.161160  0.065958
# pop_90        0.000019  0.155599  0.065399
# pop_80       -0.001125  0.152214  0.065166
# pop_70       -0.002640  0.147216  0.065604
# hsg_10        0.003582  0.167394  0.064572
# hsg_00        0.001670  0.162300  0.064103
# hsg_90       -0.000610  0.156885  0.064390
# hsg_80       -0.001218  0.152686  0.064710
# hsg_70       -0.002217  0.148744  0.065650
# lat          -0.004457  0.004205 -0.022093
# long         -0.001977  0.060324 -0.140605
# ind_dis      -0.015642 -0.014417  0.013703
# land_sqmi     0.060116  0.027470  0.093487
# pop_den       0.000367  0.177611  0.055151
# hsg_den      -0.001079  0.176458  0.051760
# pct_dpop_00   0.034988  0.100500  0.008774
# pct_dpop_90   0.018546  0.062101 -0.040410
# pct_dhsg_80   0.031589  0.106345 -0.006610
# pct_dhsg_90   0.027036  0.092786 -0.004038
# pct_dhsg_00   0.008978  0.056919 -0.071360
# pct_dpop_80   0.022390  0.108286 -0.021833
# h_sold_07     0.015566  0.147630  0.057038
# h_sold_08     0.013675  0.172194  0.070855
# h_sold_09     0.015709  0.156924  0.064453
# h_sold_10     0.016142  0.166456  0.068525
# h_sold_11     0.014034  0.155983  0.068970
# h_sold_12     0.013554  0.157938  0.068598
# h_sold_13     0.014543  0.159367  0.068326
# ...                ...       ...       ...
# ps_rg_acr_12  0.105564 -0.008788 -0.052095
# ps_rg_acr_07  0.102307 -0.013670 -0.044819
# bdg_fm_12     0.113514  0.011398 -0.036125
# bdg_fm_07     0.112636  0.017579 -0.026282
# bdg_acr_12    0.112195 -0.017812  0.020295
# bdg_acr_07    0.094762 -0.010779  0.051073
# pst_fm_12     0.099149  0.012540 -0.058641
# pst_fm_07     0.106313  0.027768 -0.046748
# pst_acr_12    0.103740 -0.016776 -0.050097
# pst_acr_07    0.105947 -0.012935 -0.042379
# cnv_fm_12     0.013294 -0.063812  0.134109
# cnv_fm_07    -0.001539 -0.010326  0.112346
# cnv_acr_12   -0.003563 -0.073378  0.116254
# cnv_acr_07    0.007074 -0.058894  0.121914
# ins_fm_12     0.042653 -0.051835  0.150741
# ins_fm_07     0.035707 -0.063807  0.135372
# ins_acr_12    0.004844 -0.054568  0.168290
# ins_acr_07    0.005386 -0.041578  0.174655
# cp_ot_fm_02   0.084832 -0.027137  0.066185
# cp_ot_acr_02  0.039905 -0.067723  0.142752
# cp_id_fm_02   0.071073 -0.035114  0.060098
# cp_id_acr_02  0.029876 -0.073018  0.129073
# cp_fl_fm_02   0.076902  0.034071  0.011347
# cp_fl_acr_02  0.011946 -0.026288  0.097768
# cp_sm_fm_02   0.001111 -0.000239  0.028263
# cp_sm_acr_02  0.006090 -0.004796  0.047595
# wd_fm_02      0.085350 -0.000864 -0.041435
# wd_acr_02     0.084102 -0.032158 -0.022086
# wd_p1_fm_02   0.101701  0.010782 -0.069136
# wd_p1_acr_02  0.090691 -0.013339 -0.044290
#
# [188 rows x 3 columns]

# %%
rescale = 50
pc1_vx = rescale * vec123_df['PC1']
pc1_vy2 = rescale * vec123_df['PC2']
pc1_vy3 = rescale * vec123_df['PC3']

# %%
pc12_df[pc12_df['cluster']=='orange']
# Out:
#                  PC1        PC2 cluster
# davidson   -6.596236  22.251171  orange
# hamilton   -4.445827  10.979543  orange
# knox        2.128732  13.880123  orange
# shelby     -5.322759  18.135126  orange
# williamson  2.507069  12.934919  orange
